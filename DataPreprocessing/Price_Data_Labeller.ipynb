# %%
import os
import pymysql
import pandas as pd
import numpy as np
import re
from pandas.io import sql
import MySQLdb
from sqlalchemy import create_engine

# %%
os.listdir(path='.')
'''
    For the given path, get the List of all files in the directory tree 
'''
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
def price_data_preprocessor(file):
    
    KO_cf = pd.read_excel(file)
    actual_filename = os.path.basename(file) # Getting filename from filepath
    company_name = actual_filename.split('_')[0] # Company Ticker Symbol
    KO_cf.insert(0, 'Company', company_name.upper())
    KO_cf_as_string = KO_cf.astype(str)
    # Denoting negative values with minus (-) instead of brackets ()
    for i in range(1, len(KO_cf_as_string.columns)):
        KO_cf.iloc[ : , i ] = KO_cf_as_string.iloc[ : , i ].replace({'\$':'', '%':'', ',':''}, regex = True)
    from datetime import datetime
    orig_dates_list = KO_cf['Date'].tolist()
    converted_dates_list = []
    for element in orig_dates_list:
        datetime_obj = datetime.strptime(element, '%b %d %Y')
        converted_dates_list.append(datetime_obj)
    KO_cf.insert(1, 'Time', converted_dates_list)

    engine = create_engine("mysql+pymysql://pythonlink:pythonlinkp@localhost:3306/stock_forecast_v1")
    KO_cf.to_sql('price_data_500', con= engine, if_exists= 'append', index = False, index_label = False)

# %%
for file in getListOfFiles('.'):
    if file.endswith(".xlsx"):
        if file.find('historical_quotes') != -1:
            print(file)
            price_data_preprocessor(file)
            print('Passed Through')
# Out:
# .\Consumer_Discretionary\AdvanceAutoPartsAAP\aap_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\AutoZoneAZO\azo_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\BookingHoldingsBKNG\bkng_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\BorgWarnerBWA\bwa_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\CarMaxKMX\kmx_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\CarnivalCorporationCCL\ccl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\ChipotleMexicanGrillCMG\cmg_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\DardenRestaurantsDRI\dri_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\DollarTreeDLTR\dltr_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\DominoesPizzaDPZ\dpz_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\DRHortonDHI\dhi_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\eBAYEBAY\ebay_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\ExpediaGroupEXPE\expe_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\FordMotorCompanyF\f_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\GapIncGPS\gps_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\GarminLtdGRMN\grmn_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\Genuine Parts Company (GPC)\gpc_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\HAndRBlockIncHRB\hrb_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\HanesbrandsIncHBI\hbi_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\HarleyDavidsonHOG\hog_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\HasbroHAS\has_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\HomeDepotHD\hd_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\KohlsCorporationKSS\kss_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\LBrandsLB\lb_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\Legett & Platt Inc (LEG)\leg_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\LennarCorporationLEN\len_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\LKQCorporationLKQ\lkq_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\Lowe's Companies (LOW)\low_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\MarriottInternationalMAR\mar_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\McDonaldsCorporationMCD\mcd_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\MGMResortsInternationalMGM\mgm_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\MohawkIndustriesMHK\mhk_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\NewellsBrandsIncNWL\nwl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\NikeNKE\nke_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\NordstromJWN\jwn_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\NVRIncNVR\nvr_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\OReillyAutomotiveORLY\orly_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\PulteGroupPHM\phm_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\PVHCorpPVH\pvh_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\RalphLaurenRL\rl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\Ross Stores (ROST)\rost_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\RoyalCaribbeanCruisesRCL\rcl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\StarbucksCorpSBUX\sbux_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\TapestryIncTPR\tpr_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\Target\tgt_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\TiffanyAndCoTIF\tif_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\TJXCompaniesTJX\tjx_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\TractorSupplyCompanyTSCO\tsco_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\UltaBeautyIncULTA\ulta_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\UnderArmourUAA\uaa_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\VF Corporation (VFC)\vfc_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\WhirlpoolCorpWHR\whr_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\WynnResortsWYNN\wynn_historical_quotes.xlsx
# Passed Through
# .\Consumer_Discretionary\YumBrandsIncYUM\yum_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Altria\mo_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\ArcherDanielsMidlandCompanyADM\adm_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\BG\bg_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\BGS\bgs_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Brown-Forman Corporation\bf.b_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\BTI\bti_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\CampbellsSoupCPB\cpb_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\CASY\casy_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\CENT\cent_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\ChurchAndDwightCHD\chd_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Coca-Cola\ko_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Colgate-Palmolive Company\cl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\ConAgraBrandsCAG\cag_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\ConstellationBrandsSTZ\stz_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\CostcoCOST\cost_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\DAR\dar_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\DEO\deo_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\EsteeLauderCompaniesEL\el_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\FDP\fdp_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\FIZZ\fizz_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\FLO\flo_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\GeneralMillsGIS\gis_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\HAIN\hain_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\HLF\hlf_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Hormel Foods Company (HRL)\hrl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\JMSmuckerCompanySJM\sjm_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\JSAIY\jsaiy_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\KelloggCompanyK\k_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Kimberly-Clarke Corporation (KMB)\kmb_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\KrogerCompanyKR\kr_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\McCormackAndCompanyMKC\mkc_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\MED\med_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\MolsonCoorsBrewingCompanyTAP\tap_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\MondelezInternationalMDLZ\mdlz_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\MonsterBeverageCorporationMNST\mnst_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\MRWSY\mrwsy_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\PepsiCo\pep_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\PhilipMorrisInternationalPM\pm_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Procter & Gamble (PG)\pg_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\PSMT\psmt_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\RAD\rad_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\REED\reed_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\SAM\sam_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\STKL\stkl_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Sysco Corporation (SYY)\syy_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\The Clorox Company (CLX)\clx_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\TheHersheyCompanyHSY\hsy_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\THS\ths_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\TysonFoodsTSN\tsn_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\UNFI\unfi_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\USNA\usna_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\VERU\veru_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\VFF\vff_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Walgreens Boots Alliance (WBA)\wba_historical_quotes.xlsx
# Passed Through
# .\Consumer_Staples\Walmart Inc. (WMT)\wmt_historical_quotes.xlsx
# Passed Through
# .\Energy\BP\bp_historical_quotes.xlsx
# Passed Through
# .\Energy\CabotOilAndGasCorporationCOG\cog_historical_quotes.xlsx
# Passed Through
# .\Energy\Chevron Corporation (CVX)\cvx_historical_quotes.xlsx
# Passed Through
# .\Energy\CLNE\clne_historical_quotes.xlsx
# Passed Through
# .\Energy\CNXResourcesCNX\cnx_historical_quotes.xlsx
# Passed Through
# .\Energy\ConchoResourcesCXO\cxo_historical_quotes.xlsx
# Passed Through
# .\Energy\ConocoPhillipsCOP\cop_historical_quotes.xlsx
# Passed Through
# .\Energy\CPE\cpe_historical_quotes.xlsx
# Passed Through
# .\Energy\DevonEnergyCorporationDVN\dvn_historical_quotes.xlsx
# Passed Through
# .\Energy\EOGResourcesEOG\eog_historical_quotes.xlsx
# Passed Through
# .\Energy\EPD\epd_historical_quotes.xlsx
# Passed Through
# .\Energy\EQTCorpEQT\eqt_historical_quotes.xlsx
# Passed Through
# .\Energy\ERF\erf_historical_quotes.xlsx
# Passed Through
# .\Energy\Exxon Mobil Corporation (XOM)\xom_historical_quotes.xlsx
# Passed Through
# .\Energy\GLP\glp_historical_quotes.xlsx
# Passed Through
# .\Energy\GreenPlainsGPRE\gpre_historical_quotes.xlsx
# Passed Through
# .\Energy\HaliburtonCompanyHAL\hal_historical_quotes.xlsx
# Passed Through
# .\Energy\HessCorporationHES\hes_historical_quotes.xlsx
# Passed Through
# .\Energy\HollyFrontierCorpHFC\hfc_historical_quotes.xlsx
# Passed Through
# .\Energy\IonGeophysicalIO\io_historical_quotes.xlsx
# Passed Through
# .\Energy\MarathonOilCorporationMRO\mro_historical_quotes.xlsx
# Passed Through
# .\Energy\NAT\nat_historical_quotes.xlsx
# Passed Through
# .\Energy\NationalOilwellVarcoNOV\nov_historical_quotes.xlsx
# Passed Through
# .\Energy\NaturalGasServicesNGS\ngs_historical_quotes.xlsx
# Passed Through
# .\Energy\NaviosMaritimeNNA\nna_historical_quotes.xlsx
# Passed Through
# .\Energy\NobleEnergyNBL\nbl_historical_quotes.xlsx
# Passed Through
# .\Energy\OII\oii_historical_quotes.xlsx
# Passed Through
# .\Energy\OneokOKE\oke_historical_quotes.xlsx
# Passed Through
# .\Energy\OxidentalPetroleumCompanyOXY\oxy_historical_quotes.xlsx
# Passed Through
# .\Energy\PacificEthanolPEIX\peix_historical_quotes.xlsx
# Passed Through
# .\Energy\PioneerNaturalResourcesCompanyPXD\pxd_historical_quotes.xlsx
# Passed Through
# .\Energy\SBOW\sbow_historical_quotes.xlsx
# Passed Through
# .\Energy\SchlumbergerSLB\slb_historical_quotes.xlsx
# Passed Through
# .\Energy\StealthGasIncGASS\gass_historical_quotes.xlsx
# Passed Through
# .\Energy\TheWilliamsCompaniesWMB\wmb_historical_quotes.xlsx
# Passed Through
# .\Energy\TNK\tnk_historical_quotes.xlsx
# Passed Through
# .\Energy\TotalSETOT\tot_historical_quotes.xlsx
# Passed Through
# .\Energy\ValeroEnergyCorpVLO\vlo_historical_quotes.xlsx
# Passed Through
# .\Energy\WorldFuelServicesINT\int_historical_quotes.xlsx
# Passed Through
# .\Energy\XEC\xec_historical_quotes.xlsx
# Passed Through
# .\Financials\Aflac\afl_historical_quotes.xlsx
# Passed Through
# .\Financials\AmericanInternationalGroupAIG\aig_historical_quotes.xlsx
# Passed Through
# .\Financials\AmeripriseFinancialAMP\amp_historical_quotes.xlsx
# Passed Through
# .\Financials\ArthurJGallagherAJG\ajg_historical_quotes.xlsx
# Passed Through
# .\Financials\AssurantAIZ\aiz_historical_quotes.xlsx
# Passed Through
# .\Financials\BerkshireHathawayBRBK\brk.b_historical_quotes.xlsx
# Passed Through
# .\Financials\BlackRockIncBLK\blk_historical_quotes.xlsx
# Passed Through
# .\Financials\Chubb\cb_historical_quotes.xlsx
# Passed Through
# .\Financials\Cincinnati Financial\cinf_historical_quotes.xlsx
# Passed Through
# .\Financials\CMEGroupCME\cme_historical_quotes.xlsx
# Passed Through
# .\Financials\DGICA\dgica_historical_quotes.xlsx
# Passed Through
# .\Financials\EIG\eig_historical_quotes.xlsx
# Passed Through
# .\Financials\EverestREGroupRE\re_historical_quotes.xlsx
# Passed Through
# .\Financials\FDS\fds_historical_quotes.xlsx
# Passed Through
# .\Financials\FNF\fnf_historical_quotes.xlsx
# Passed Through
# .\Financials\Franklin Resources (BEN)\ben_historical_quotes.xlsx
# Passed Through
# .\Financials\GlobeLifeIncGL\gl_historical_quotes.xlsx
# Passed Through
# .\Financials\HartfordFinancialServicesGroupHIG\hig_historical_quotes.xlsx
# Passed Through
# .\Financials\IntercontinentalExchangeICE\ice_historical_quotes.xlsx
# Passed Through
# .\Financials\InvescoLtdIVZ\ivz_historical_quotes.xlsx
# Passed Through
# .\Financials\LincolnNationalCorporationLNC\lnc_historical_quotes.xlsx
# Passed Through
# .\Financials\LoewsCorporationL\l_historical_quotes.xlsx
# Passed Through
# .\Financials\MarketAxessHoldingsIncMKTX\mktx_historical_quotes.xlsx
# Passed Through
# .\Financials\MarshAndMcLennanCompaniesMMC\mmc_historical_quotes.xlsx
# Passed Through
# .\Financials\MetLifeMET\met_historical_quotes.xlsx
# Passed Through
# .\Financials\MoodysCorporationMCO\mco_historical_quotes.xlsx
# Passed Through
# .\Financials\MSCI\msci_historical_quotes.xlsx
# Passed Through
# .\Financials\NasdaqIncNDAQ\ndaq_historical_quotes.xlsx
# Passed Through
# .\Financials\NEWT\newt_historical_quotes.xlsx
# Passed Through
# .\Financials\PrincipalFinancialGroupIncPFG\pfg_historical_quotes.xlsx
# Passed Through
# .\Financials\PrudentialFinancialPRU\pru_historical_quotes.xlsx
# Passed Through
# .\Financials\S&P Global Inc (SPGI)\spgi_historical_quotes.xlsx
# Passed Through
# .\Financials\SEIC\seic_historical_quotes.xlsx
# Passed Through
# .\Financials\SLF\slf_historical_quotes.xlsx
# Passed Through
# .\Financials\STC\stc_historical_quotes.xlsx
# Passed Through
# .\Financials\T. Rowe Price\trow_historical_quotes.xlsx
# Passed Through
# .\Financials\TheAllstateCorporationALL\all_historical_quotes.xlsx
# Passed Through
# .\Financials\TheProgressiveCorporationPGR\pgr_historical_quotes.xlsx
# Passed Through
# .\Financials\TheTravelersCompaniesTRV\trv_historical_quotes.xlsx
# Passed Through
# .\Financials\UnumGroupUNM\unm_historical_quotes.xlsx
# Passed Through
# .\Financials\WDR\wdr_historical_quotes.xlsx
# Passed Through
# .\Financials\WillisTowersWatsonWLTW\wltw_historical_quotes.xlsx
# Passed Through
# .\Financials\WRBerkleyCorpWRB\wrb_historical_quotes.xlsx
# Passed Through
# .\Healthcare\Abbott Laboratories\abt_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AbiomedABMD\abmd_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AgilentTechnologiesA\a_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AlexionPharmaceuticalsALXN\alxn_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AlignTechnologyALGN\algn_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AmeriSourceBergenABC\abc_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AmgenAMGN\amgn_historical_quotes.xlsx
# Passed Through
# .\Healthcare\AnthemANTM\antm_historical_quotes.xlsx
# Passed Through
# .\Healthcare\BaxterInternationalIncBAX\bax_historical_quotes.xlsx
# Passed Through
# .\Healthcare\Becton Dickinson and Company (BDX)\bdx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\BiogenBIIB\biib_historical_quotes.xlsx
# Passed Through
# .\Healthcare\BostonScientificCorpBSX\bsx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\BristolMyersSquibbCompanyBMY\bmy_historical_quotes.xlsx
# Passed Through
# .\Healthcare\Cardinal Health Inc. (CAH)\cah_historical_quotes.xlsx
# Passed Through
# .\Healthcare\CenteneCNC\cnc_historical_quotes.xlsx
# Passed Through
# .\Healthcare\CernerCorporationCERN\cern_historical_quotes.xlsx
# Passed Through
# .\Healthcare\CignaCorporationCI\ci_historical_quotes.xlsx
# Passed Through
# .\Healthcare\CVSHealthCorporationCVS\cvs_historical_quotes.xlsx
# Passed Through
# .\Healthcare\DanaherCorporationDHR\dhr_historical_quotes.xlsx
# Passed Through
# .\Healthcare\DaVitaIncDVA\dva_historical_quotes.xlsx
# Passed Through
# .\Healthcare\DentsplySironaIncXRAY\xray_historical_quotes.xlsx
# Passed Through
# .\Healthcare\DexComIncDXCM\dxcm_historical_quotes.xlsx
# Passed Through
# .\Healthcare\EdwardsLifesciencesCorporationEW\ew_historical_quotes.xlsx
# Passed Through
# .\Healthcare\EliLillyAndCompanyLLY\lly_historical_quotes.xlsx
# Passed Through
# .\Healthcare\GileadSciencesIncGILD\gild_historical_quotes.xlsx
# Passed Through
# .\Healthcare\HenryScheinHSIC\hsic_historical_quotes.xlsx
# Passed Through
# .\Healthcare\HologicHOLX\holx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\HumanaIncHUM\hum_historical_quotes.xlsx
# Passed Through
# .\Healthcare\IdexxLaboratoriesIDEXX\idxx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\IlluminaILMN\ilmn_historical_quotes.xlsx
# Passed Through
# .\Healthcare\IncyteCorporationINCY\incy_historical_quotes.xlsx
# Passed Through
# .\Healthcare\IntuitiveSurgicalISRG\isrg_historical_quotes.xlsx
# Passed Through
# .\Healthcare\Johnson & Johnson\jnj_historical_quotes.xlsx
# Passed Through
# .\Healthcare\LaboratoryOfAmericaHoldingsLH\lh_historical_quotes.xlsx
# Passed Through
# .\Healthcare\McKessonCorpMCK\mck_historical_quotes.xlsx
# Passed Through
# .\Healthcare\MerckMRK\mrk_historical_quotes.xlsx
# Passed Through
# .\Healthcare\MettlerToledoInternationalMTD\mtd_historical_quotes.xlsx
# Passed Through
# .\Healthcare\PerkinElmerIncPKI\pki_historical_quotes.xlsx
# Passed Through
# .\Healthcare\PerrigoCompanyPlcPRGO\prgo_historical_quotes.xlsx
# Passed Through
# .\Healthcare\PfizerIncPFE\pfe_historical_quotes.xlsx
# Passed Through
# .\Healthcare\QuestDiagnosticsIncDGX\dgx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\RegeneronPharmaceuticalsREGN\regn_historical_quotes.xlsx
# Passed Through
# .\Healthcare\ResMedIncRMD\rmd_historical_quotes.xlsx
# Passed Through
# .\Healthcare\SterisSTE\ste_historical_quotes.xlsx
# Passed Through
# .\Healthcare\StrykerCorpSYK\syk_historical_quotes.xlsx
# Passed Through
# .\Healthcare\TelefexIncTFX\tfx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\TheCooperCompaniesIncCOO\coo_historical_quotes.xlsx
# Passed Through
# .\Healthcare\ThermoFisherScientificTMO\tmo_historical_quotes.xlsx
# Passed Through
# .\Healthcare\UnitedHealthGroupUNH\unh_historical_quotes.xlsx
# Passed Through
# .\Healthcare\UniversalHealthServicesUHS\uhs_historical_quotes.xlsx
# Passed Through
# .\Healthcare\VarianMedicalSystemsVAR\var_historical_quotes.xlsx
# Passed Through
# .\Healthcare\VertexPharmaceuticalsVRTX\vrtx_historical_quotes.xlsx
# Passed Through
# .\Healthcare\WatersCorpWAT\wat_historical_quotes.xlsx
# Passed Through
# .\Healthcare\WestPharmaceuticalServicesIncWST\wst_historical_quotes.xlsx
# Passed Through
# .\Healthcare\ZimmerBiometHoldingsZBH\zbh_historical_quotes.xlsx
# Passed Through
# .\Industrials\3M\mmm_historical_quotes.xlsx
# Passed Through
# .\Industrials\AlaskaAirGroupALK\alk_historical_quotes.xlsx
# Passed Through
# .\Industrials\AmericanAirlinesAAL\aal_historical_quotes.xlsx
# Passed Through
# .\Industrials\AmetekAME\ame_historical_quotes.xlsx
# Passed Through
# .\Industrials\AO Smith (AOS)\aos_historical_quotes.xlsx
# Passed Through
# .\Industrials\BoeingBA\ba_historical_quotes.xlsx
# Passed Through
# .\Industrials\CaterpillarIncCAT\cat_historical_quotes.xlsx
# Passed Through
# .\Industrials\CHRobinsonWorldwideCHRW\chrw_historical_quotes.xlsx
# Passed Through
# .\Industrials\Cintas (CTAS)\ctas_historical_quotes.xlsx
# Passed Through
# .\Industrials\CopartIncCPRT\cprt_historical_quotes.xlsx
# Passed Through
# .\Industrials\CSXCorporationCSX\csx_historical_quotes.xlsx
# Passed Through
# .\Industrials\CumminsIncCMI\cmi_historical_quotes.xlsx
# Passed Through
# .\Industrials\DeereAndCompanyDE\de_historical_quotes.xlsx
# Passed Through
# .\Industrials\DeltaAirlinesDAL\dal_historical_quotes.xlsx
# Passed Through
# .\Industrials\Dover (DOV)\dov_historical_quotes.xlsx
# Passed Through
# .\Industrials\Emerson Electric (EMR)\emr_historical_quotes.xlsx
# Passed Through
# .\Industrials\EquifaxEFX\efx_historical_quotes.xlsx
# Passed Through
# .\Industrials\ExpiditorsInternationalOfWashington (EXPD)\expd_historical_quotes.xlsx
# Passed Through
# .\Industrials\FastenalCompanyFAST\fast_historical_quotes.xlsx
# Passed Through
# .\Industrials\FedExCorporation\fdx_historical_quotes.xlsx
# Passed Through
# .\Industrials\FlowserveFLS\fls_historical_quotes.xlsx
# Passed Through
# .\Industrials\GeneralDynamicsGD\gd_historical_quotes.xlsx
# Passed Through
# .\Industrials\GeneralElectricCompanyGE\ge_historical_quotes.xlsx
# Passed Through
# .\Industrials\HoneywellHON\hon_historical_quotes.xlsx
# Passed Through
# .\Industrials\IDEXCorpIEX\iex_historical_quotes.xlsx
# Passed Through
# .\Industrials\IllinoisToolWorksITW\itw_historical_quotes.xlsx
# Passed Through
# .\Industrials\JacobsEngineeringGroupJ\j_historical_quotes.xlsx
# Passed Through
# .\Industrials\JBHuntTransportServicesJBHT\jbht_historical_quotes.xlsx
# Passed Through
# .\Industrials\JohnsonControlsInternationalJCI\jci_historical_quotes.xlsx
# Passed Through
# .\Industrials\KansasCitySouthernKSU\ksu_historical_quotes.xlsx
# Passed Through
# .\Industrials\LockheedMartinCorporationLMT\lmt_historical_quotes.xlsx
# Passed Through
# .\Industrials\MascoCorporationMAS\mas_historical_quotes.xlsx
# Passed Through
# .\Industrials\NorfolkSouthernCorpNSC\nsc_historical_quotes.xlsx
# Passed Through
# .\Industrials\NorthropGrummanCorpNOC\noc_historical_quotes.xlsx
# Passed Through
# .\Industrials\OldDominionFreightLineIncODFL\odfl_historical_quotes.xlsx
# Passed Through
# .\Industrials\PaccarIncPCAR\pcar_historical_quotes.xlsx
# Passed Through
# .\Industrials\ParkerHannafinCorporationPH\ph_historical_quotes.xlsx
# Passed Through
# .\Industrials\PentairPNR\pnr_historical_quotes.xlsx
# Passed Through
# .\Industrials\QuantaServicesPWR\pwr_historical_quotes.xlsx
# Passed Through
# .\Industrials\RaytheonTechnologiesCorpRTX\rtx_historical_quotes.xlsx
# Passed Through
# .\Industrials\RepublicServicesRSG\rsg_historical_quotes.xlsx
# Passed Through
# .\Industrials\RobertHalfInternationalRHI\rhi_historical_quotes.xlsx
# Passed Through
# .\Industrials\RockwellAutomationROK\rok_historical_quotes.xlsx
# Passed Through
# .\Industrials\RollinsIncROL\rol_historical_quotes.xlsx
# Passed Through
# .\Industrials\RoperTechnologiesROP\rop_historical_quotes.xlsx
# Passed Through
# .\Industrials\SnapOnIncSNA\sna_historical_quotes.xlsx
# Passed Through
# .\Industrials\SouthwestAirlinesLUV\luv_historical_quotes.xlsx
# Passed Through
# .\Industrials\StanleyBlackAndDeckerSWK\swk_historical_quotes.xlsx
# Passed Through
# .\Industrials\TextronIncTXT\txt_historical_quotes.xlsx
# Passed Through
# .\Industrials\TraneTechnologiesTT\tt_historical_quotes.xlsx
# Passed Through
# .\Industrials\TransDigmGroupIncTDG\tdg_historical_quotes.xlsx
# Passed Through
# .\Industrials\UnionPacificCorporationUNP\unp_historical_quotes.xlsx
# Passed Through
# .\Industrials\UnitedAirlinesHoldingsUAL\ual_historical_quotes.xlsx
# Passed Through
# .\Industrials\UnitedParcelServiceUPS\ups_historical_quotes.xlsx
# Passed Through
# .\Industrials\UnitedRentalsURI\uri_historical_quotes.xlsx
# Passed Through
# .\Industrials\WabtecCorpWAB\wab_historical_quotes.xlsx
# Passed Through
# .\Industrials\WasteManagementWM\wm_historical_quotes.xlsx
# Passed Through
# .\Industrials\WWGraingerGWW\gww_historical_quotes.xlsx
# Passed Through
# .\Materials\AGI\agi_historical_quotes.xlsx
# Passed Through
# .\Materials\Air Products and Chemicals Inc (APD)\apd_historical_quotes.xlsx
# Passed Through
# .\Materials\Albemarle Corporation (ALB)\alb_historical_quotes.xlsx
# Passed Through
# .\Materials\ASH\ash_historical_quotes.xlsx
# Passed Through
# .\Materials\AUY\auy_historical_quotes.xlsx
# Passed Through
# .\Materials\AveryDennisonCorporationAVY\avy_historical_quotes.xlsx
# Passed Through
# .\Materials\BallCorporationBLL\bll_historical_quotes.xlsx
# Passed Through
# .\Materials\BBL\bbl_historical_quotes.xlsx
# Passed Through
# .\Materials\BCPC\bcpc_historical_quotes.xlsx
# Passed Through
# .\Materials\CaledoniaMiningCorpCMCL\cmcl_historical_quotes.xlsx
# Passed Through
# .\Materials\CCK\cck_historical_quotes.xlsx
# Passed Through
# .\Materials\CelaneseCorpCE\ce_historical_quotes.xlsx
# Passed Through
# .\Materials\CFIndustriesHoldingsCF\cf_historical_quotes.xlsx
# Passed Through
# .\Materials\CommercialMetalsCompanyCMC\cmc_historical_quotes.xlsx
# Passed Through
# .\Materials\EastmanChemicalCompanyEMN\emn_historical_quotes.xlsx
# Passed Through
# .\Materials\Ecolab (ECL)\ecl_historical_quotes.xlsx
# Passed Through
# .\Materials\FMCCorporationFMC\fmc_historical_quotes.xlsx
# Passed Through
# .\Materials\FreeportMcMoRanFCX\fcx_historical_quotes.xlsx
# Passed Through
# .\Materials\FSI\fsi_historical_quotes.xlsx
# Passed Through
# .\Materials\FSM\fsm_historical_quotes.xlsx
# Passed Through
# .\Materials\GoldenStarResourcesGSS\gss_historical_quotes.xlsx
# Passed Through
# .\Materials\GPK\gpk_historical_quotes.xlsx
# Passed Through
# .\Materials\HawkinsHWKN\hwkn_historical_quotes.xlsx
# Passed Through
# .\Materials\IAG\iag_historical_quotes.xlsx
# Passed Through
# .\Materials\InternationalFlavoursAndFragrancesIFF\iff_historical_quotes.xlsx
# Passed Through
# .\Materials\InternationalPaperCompanyIP\ip_historical_quotes.xlsx
# Passed Through
# .\Materials\LPX\lpx_historical_quotes.xlsx
# Passed Through
# .\Materials\MartinMariettaMaterialsMLM\mlm_historical_quotes.xlsx
# Passed Through
# .\Materials\MTRN\mtrn_historical_quotes.xlsx
# Passed Through
# .\Materials\NewmontCorporationNEM\nem_historical_quotes.xlsx
# Passed Through
# .\Materials\Nucor Corporation (NUE)\nue_historical_quotes.xlsx
# Passed Through
# .\Materials\PAAS\paas_historical_quotes.xlsx
# Passed Through
# .\Materials\PackagingCorporationOfAmericaPKG\pkg_historical_quotes.xlsx
# Passed Through
# .\Materials\PKX\pkx_historical_quotes.xlsx
# Passed Through
# .\Materials\PPG Industries (PPG)\ppg_historical_quotes.xlsx
# Passed Through
# .\Materials\RPMInternationalRPM\rpm_historical_quotes.xlsx
# Passed Through
# .\Materials\SCCO\scco_historical_quotes.xlsx
# Passed Through
# .\Materials\ScottsMiracleGroSMG\smg_historical_quotes.xlsx
# Passed Through
# .\Materials\SealedAirCorpSEE\see_historical_quotes.xlsx
# Passed Through
# .\Materials\SilganHoldingsSLGN\slgn_historical_quotes.xlsx
# Passed Through
# .\Materials\SSRMiningCorpSSRM\ssrm_historical_quotes.xlsx
# Passed Through
# .\Materials\StepanCompanySCL\scl_historical_quotes.xlsx
# Passed Through
# .\Materials\SXT\sxt_historical_quotes.xlsx
# Passed Through
# .\Materials\The Sherwin-Williams Company (SHW)\shw_historical_quotes.xlsx
# Passed Through
# .\Materials\ValeSA_VALE\vale_historical_quotes.xlsx
# Passed Through
# .\Materials\VulcanMaterialsVMC\vmc_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AccentureACN\acn_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AdobeADBE\adbe_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AdvancedMicroDevicesAMD\amd_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AkamiTechnologiesAKAM\akam_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AllianceDataSystemsADS\ads_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\Amazon\amzn_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AmphenolCorporationAPH\aph_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AnalogDevicesADI\adi_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AnsysANSS\anss_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\Apple Inc\aapl_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AppliedMaterialsIncAMAT\amat_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\AutoDeskADSK\adsk_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\Automatic Data Processing\adp_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\BroadcomAVGO\avgo_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\BroadridgeFinancialSolutionsBR\br_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\CadenceDesignSystemsCDNS\cdns_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\CiscoSystemsCSCO\csco_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\CitrixSystemsCTXS\ctxs_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\CognizantTechnologySolutionsCorp\ctsh_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\CorningIncGLW\glw_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\F5NetworksIncFFIV\ffiv_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\FidelityNationalInformationServicesFIS\fis_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\FiservIncFISV\fisv_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\FlirSystemsFLIR\flir_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\GartnerIncIT\it_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\GlobalPaymentsIncGPN\gpn_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\Google (GOOGL)\googl_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\HPIncHPQ\hpq_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\IBM\ibm_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\IntelCorporationINTC\intc_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\IntuitINTU\intu_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\IPHPhotonicsCorpIPGP\ipgp_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\JackHenryAndAssociatesJKHY\jkhy_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\JuniperNetworksJNPR\jnpr_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\KLACorporationKLAC\klac_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\LamResearchCorporationLRCX\lrcx_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\LeidosHoldingsLDOS\ldos_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\MastercardMA\ma_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\MicrochipTechnologyIncMCHP\mchp_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\MicronTechnologyMU\mu_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\MicrosoftMSFT\msft_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\MotorolaSolutionsMSI\msi_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\NetAppIncNTAP\ntap_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\NortonLifeLockNLOK\nlok_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\NVIDIAnvda\nvda_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\OracleCorporationORCL\orcl_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\PaychexIncPAYX\payx_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\QualcommQCOM\qcom_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\SalesforceCRM\crm_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\SeagateTechnologySTX\stx_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\SkyworksSolutionsSWKS\swks_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\SynopsysSNPS\snps_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\TEConnectivityTEL\tel_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\TexasInstrumentsIncTXN\txn_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\VeriSignVRSN\vrsn_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\Visa\v_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\WesternDigitalCorporationWDC\wdc_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\WesternUnionCompanyWU\wu_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\XeroxHoldingsCompanyXRX\xrx_historical_quotes.xlsx
# Passed Through
# .\TechAndIT\XilinxXLNX\xlnx_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\ActivisionBlizzardATVI\atvi_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\AMX\amx_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\AT&T\t_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\ATNI\atni_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\BIDU\bidu_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\CCOI\ccoi_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\CenturyLinkIncCTL\ctl_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\CNK\cnk_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\ComcastCorpCMCSA\cmcsa_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\DiscoveryIncDISCA\disca_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\DishNetworkCorporationDISH\dish_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\Disney\dis_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\ElectronicArtsEA\ea_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\EWScripps_SSP\ssp_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\GLUU\gluu_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\GTN\gtn_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\HHS\hhs_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\InterpublicGroupOfCompaniesIncIPG\ipg_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\KTCorp_KT\kt_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\LBTYA\lbtya_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\LiveNationEntertainmentLYV\lyv_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\MBT\mbt_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\NetEaseNTES\ntes_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\NetflixNFLX\nflx_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\NXST\nxst_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\NYT\nyt_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\OmnicomGroupOMC\omc_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\OrangeORAN\oran_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\SFTBF\sftbf_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\ShawCommunicationsSJR\sjr_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\SINA\sina_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\SIRI\siri_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\SKTelecom_SKM\skm_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\SOHU\sohu_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\TakeTwoInteractiveSoftwareTTWO\ttwo_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\TCEHY\tcehy_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\TDS\tds_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\TelenorASA_TELNY\telny_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\TGNA\tgna_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\TU\tu_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\USM\usm_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\VerizonVZ\vz_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\ViacomCBS_VIAC\viac_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\VodafoneVOD\vod_historical_quotes.xlsx
# Passed Through
# .\TelecomsAndCommunicationServices\WWE\wwe_historical_quotes.xlsx
# Passed Through
# .\Utilities\AESCorporationAES\aes_historical_quotes.xlsx
# Passed Through
# .\Utilities\AlliantEnergyCorporationLNT\lnt_historical_quotes.xlsx
# Passed Through
# .\Utilities\AmerenCorporationAEE\aee_historical_quotes.xlsx
# Passed Through
# .\Utilities\AmericanElectricPowerCompanyAEP\aep_historical_quotes.xlsx
# Passed Through
# .\Utilities\AmericanWaterWorksAWK\awk_historical_quotes.xlsx
# Passed Through
# .\Utilities\ARTNA\artna_historical_quotes.xlsx
# Passed Through
# .\Utilities\Atmos Energy Corporation (ATO)\ato_historical_quotes.xlsx
# Passed Through
# .\Utilities\BIP\bip_historical_quotes.xlsx
# Passed Through
# .\Utilities\CenterPointEnergyCNP\cnp_historical_quotes.xlsx
# Passed Through
# .\Utilities\CLPHY\clphy_historical_quotes.xlsx
# Passed Through
# .\Utilities\CMSEnergyCorporationCMS\cms_historical_quotes.xlsx
# Passed Through
# .\Utilities\Consolidated Edison Inc (ED)\ed_historical_quotes.xlsx
# Passed Through
# .\Utilities\CPYYY\cpyyy_historical_quotes.xlsx
# Passed Through
# .\Utilities\CWCO\cwco_historical_quotes.xlsx
# Passed Through
# .\Utilities\DTEEnergyCompanyDTE\dte_historical_quotes.xlsx
# Passed Through
# .\Utilities\Duke Energy Corporation\duk_historical_quotes.xlsx
# Passed Through
# .\Utilities\EdisonInternationalEIX\eix_historical_quotes.xlsx
# Passed Through
# .\Utilities\ELP\elp_historical_quotes.xlsx
# Passed Through
# .\Utilities\ENIA\enia_historical_quotes.xlsx
# Passed Through
# .\Utilities\EntergyETR\etr_historical_quotes.xlsx
# Passed Through
# .\Utilities\EONGY\eongy_historical_quotes.xlsx
# Passed Through
# .\Utilities\EversourceEnergyES\es_historical_quotes.xlsx
# Passed Through
# .\Utilities\ExelonCorporationEXC\exc_historical_quotes.xlsx
# Passed Through
# .\Utilities\FirstEnergyCorpFE\fe_historical_quotes.xlsx
# Passed Through
# .\Utilities\KEP\kep_historical_quotes.xlsx
# Passed Through
# .\Utilities\MGEE\mgee_historical_quotes.xlsx
# Passed Through
# .\Utilities\MSEX\msex_historical_quotes.xlsx
# Passed Through
# .\Utilities\NextEra Energy\nee_historical_quotes.xlsx
# Passed Through
# .\Utilities\NGG\ngg_historical_quotes.xlsx
# Passed Through
# .\Utilities\NiSourceNI\ni_historical_quotes.xlsx
# Passed Through
# .\Utilities\NRGEnergyNRG\nrg_historical_quotes.xlsx
# Passed Through
# .\Utilities\OGE\oge_historical_quotes.xlsx
# Passed Through
# .\Utilities\PinnacleWestCapitalCorpPNW\pnw_historical_quotes.xlsx
# Passed Through
# .\Utilities\POR\por_historical_quotes.xlsx
# Passed Through
# .\Utilities\PPLCorporationPPL\ppl_historical_quotes.xlsx
# Passed Through
# .\Utilities\PublicServiceEnterpriseGroupIncPEG\peg_historical_quotes.xlsx
# Passed Through
# .\Utilities\SempraEnergySRE\sre_historical_quotes.xlsx
# Passed Through
# .\Utilities\SJI\sji_historical_quotes.xlsx
# Passed Through
# .\Utilities\TAC\tac_historical_quotes.xlsx
# Passed Through
# .\Utilities\The Southern Company\so_historical_quotes.xlsx
# Passed Through
# .\Utilities\UTL\utl_historical_quotes.xlsx
# Passed Through
# .\Utilities\WECEnergyGroupWEC\wec_historical_quotes.xlsx
# Passed Through
# .\Utilities\XcelEnergyXEL\xel_historical_quotes.xlsx
# Passed Through
# .\Utilities\YORW\yorw_historical_quotes.xlsx
# Passed Through
