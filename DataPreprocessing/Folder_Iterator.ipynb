# %%
# Using OS
import os
import pathlib

# %%
os.getcwd()
# Out:
# 'C:\\Users\\conor\\Documents\\MScAIProject\\MSc_AI_Project\\Data\\Economic_Sector'

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'Consumer',
#  'Consumer_Discretionary',
#  'Consumer_Staples',
#  'Energy',
#  'Financials',
#  'Folder_Iterator.ipynb',
#  'Healthcare',
#  'Industrials',
#  'Materials',
#  'TechAndIT',
#  'TelecomsAndCommunicationServices',
#  'Utilities']

# %%
x = 'Balance Sheet'
x.find('S')
# Out:
# 8

# %%
import pandas as pd
import numpy as np
import re
import pymysql
from pandas.io import sql
import MySQLdb
from sqlalchemy import create_engine


def balsheet_preprocessor(filename):  
    
    KO_BalSheet = pd.read_excel(filename)
    KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
    KO_BalSheet = KO_BalSheet.iloc[1:]
    TKo_BalSheet = KO_BalSheet.transpose()
    TKo_BalSheet = TKo_BalSheet.rename(columns = TKo_BalSheet.iloc[0]) #Renaming columns
    Tko_BalSheet = TKo_BalSheet.iloc[1:]
    Tko_BalSheet = TKo_BalSheet.iloc[1:-1]
    Tko_BalSheet = Tko_BalSheet.loc[:, Tko_BalSheet.columns.notnull()] #Removing NaN columns
    Tko_BalSheet = Tko_BalSheet.dropna(axis = 1, how = 'all')

    # Removing all dollar signs ($) from dataframe
    # Tko_BalSheet.iloc[ : , i ] # Denoting column by index instead of name
    # https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
    for i in range(1, len(Tko_BalSheet.columns)):
        Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'\$':''}, regex = True)
        #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

    # Replacing dash values with 0
    for i in range(1, len(Tko_BalSheet.columns)):
        Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'-': 0}, regex = True)
        #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

    Tko_BalSheet_as_string = Tko_BalSheet.astype(str)

    # Denoting negative values with minus (-) instead of brackets ()
    for i in range(1, len(Tko_BalSheet_as_string.columns)):
        Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet_as_string.iloc[ : , i ].replace({'\(':'-', '\)':''}, regex = True)
        
    Tko_BalSheet.to_sql('test_table', con= engine, if_exists='append', index = False)

# %%
# dialect+driver://username:password@host:port/database

#engine = create_engine("mysql+pymysql://root:y5QLCM%12&@localhost:3306/stock_forecast_v1")
# Can you log into root
engine = create_engine("mysql+pymysql://pythonlink:pythonlinkp@localhost:3306/stock_forecast_v1")

# %%
import os
from PIL import Image

# Need to scale images so they are all the same size
# Check that I can still print images after converting to RGB
# Is this the right format for input into the model?

#Hatchback Class is 0
hatchback_list = []

count_hatchbacks = 0
count_sedans = 0
directory1 = r'Images/Hatchback_Images/All_Hatchback_Images'
directory2 = r'Images/Sedan_Images/All_Sedan_Images'
for filename in os.listdir(directory1):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        count_hatchbacks += 1
        
for filename in os.listdir(directory2):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        count_sedans += 1
        
print("Total HatchBack count", count_hatchbacks)
print("Total Sedan count", count_sedans)
print("Total Train Images = ", count_hatchbacks + count_sedans)
    
#print(hatchback_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-c0f9d69d6c2b> in <module>
#      13 directory1 = r'Images/Hatchback_Images/All_Hatchback_Images'
#      14 directory2 = r'Images/Sedan_Images/All_Sedan_Images'
# ---> 15 for filename in os.listdir(directory1):
#      16     if filename.endswith(".jpg") or filename.endswith(".png"):
#      17         count_hatchbacks += 1
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Images/Hatchback_Images/All_Hatchback_Images'

# %%
if file.endswith(".xlsx"):
            file_count += 1

# %%
file_count = 0
for filename in os.listdir(r'..\Economic_Sector\Consumer\Altria'):
    if filename.endswith(".xlsx"):
        if filename.find('Balance Sheet') != -1:
            pd.read_excel()
                #balsheet_preprocessor(filename)
                #print(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-82bb4181af5a> in <module>
#       3     if filename.endswith(".xlsx"):
#       4         if filename.find('Balance Sheet') != -1:
# ----> 5             pd.read_excel(r'filename')
#       6                 #balsheet_preprocessor(filename)
#       7                 #print(filename)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# ~\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'filename'

# %%
# Get Balance Sheets
from pathlib import Path
p = Path('.') # Path starts from current directory
engine = create_engine("mysql+pymysql://pythonlink:pythonlinkp@localhost:3306/stock_forecast_v1")
counter = 0
for root, dirs, files in os.walk(p):
    for name in files:
        if name.endswith((".xlsx")):
            if name.find('Balance Sheet') != -1:
                balsheet_preprocessor(name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-4355716aeda3> in <module>
#       8         if name.endswith((".xlsx")):
#       9             if name.find('Balance Sheet') != -1:
# ---> 10                 balsheet_preprocessor(name)
#
# <ipython-input-4-101acaea02fe> in balsheet_preprocessor(filename)
#      10 def balsheet_preprocessor(filename):
#      11
# ---> 12     KO_BalSheet = pd.read_excel(filename)
#      13     KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
#      14     KO_BalSheet = KO_BalSheet.iloc[1:]
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, parse_cols, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     348
#     349     if not isinstance(io, ExcelFile):
# --> 350         io = ExcelFile(io, engine=engine)
#     351
#     352     return io.parse(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, engine)
#     651         self._io = _stringify_path(io)
#     652
# --> 653         self._reader = self._engines[engine](self._io)
#     654
#     655     def __fspath__(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, filepath_or_buffer)
#     422             self.book = xlrd.open_workbook(file_contents=data)
#     423         elif isinstance(filepath_or_buffer, compat.string_types):
# --> 424             self.book = xlrd.open_workbook(filepath_or_buffer)
#     425         else:
#     426             raise ValueError('Must explicitly set engine if not passing in'
#
# ~\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'MO Balance Sheet - Seeking Alpha.xlsx'

# %%
os.listdir(path='.')
'''
    For the given path, get the List of all files in the directory tree 
'''
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
counter = 0
for file in getListOfFiles('.'):
    if file.endswith(".xlsx"):
        print(file)
        counter+=1
print(counter)
# Out:
# .\Consumer\Altria\MO Balance Sheet - Seeking Alpha.xlsx
# .\Consumer\Altria\MO Cash Flow - Seeking Alpha.xlsx
# .\Consumer\Altria\MO Income Statement - Seeking Alpha.xlsx
# .\Consumer\Altria\mo_historical_quotes.xlsx
# .\Consumer\Brown-Forman Corporation\BF.B Balance Sheet - Seeking Alpha.xlsx
# .\Consumer\Brown-Forman Corporation\BF.B Cash Flow - Seeking Alpha.xlsx
# .\Consumer\Brown-Forman Corporation\BF.B Income Statement - Seeking Alpha.xlsx
cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\FordMotorCompanyF\F Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\FordMotorCompanyF\f_historical_quotes.xlsx
# .\Consumer_Discretionary\GapIncGPS\GPS Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\GapIncGPS\GPS Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\GapIncGPS\GPS Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\GapIncGPS\gps_historical_quotes.xlsx
# .\Consumer_Discretionary\GarminLtdGRMN\GRMN Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\GarminLtdGRMN\GRMN Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\GarminLtdGRMN\GRMN Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\GarminLtdGRMN\grmn_historical_quotes.xlsx
# .\Consumer_Discretionary\Genuine Parts Company (GPC)\GPC Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Genuine Parts Company (GPC)\GPC Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Genuine Parts Company (GPC)\GPC Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Genuine Parts Company (GPC)\gpc_historical_quotes.xlsx
# .\Consumer_Discretionary\HAndRBlockIncHRB\HRB Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HAndRBlockIncHRB\HRB Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HAndRBlockIncHRB\HRB Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HAndRBlockIncHRB\hrb_historical_quotes.xlsx
# .\Consumer_Discretionary\HarleyDavidsonHOG\HOG Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HarleyDavidsonHOG\HOG Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HarleyDavidsonHOG\HOG Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HarleyDavidsonHOG\hog_historical_quotes.xlsx
# .\Consumer_Discretionary\HasbroHAS\HAS Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HasbroHAS\HAS Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HasbroHAS\HAS Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HasbroHAS\has_historical_quotes.xlsx
# .\Consumer_Discretionary\HomeDepotHD\HD Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HomeDepotHD\HD Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HomeDepotHD\HD Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\HomeDepotHD\hd_historical_quotes.xlsx
# .\Consumer_Discretionary\KohlsCorporationKSS\KSS Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\KohlsCorporationKSS\KSS Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\KohlsCorporationKSS\KSS Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\KohlsCorporationKSS\kss_historical_quotes.xlsx
# .\Consumer_Discretionary\LBrandsLB\LB Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LBrandsLB\LB Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LBrandsLB\LB Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LBrandsLB\lb_historical_quotes.xlsx
# .\Consumer_Discretionary\Legett & Platt Inc (LEG)\LEG Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Legett & Platt Inc (LEG)\LEG Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Legett & Platt Inc (LEG)\LEG Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Legett & Platt Inc (LEG)\leg_historical_quotes.xlsx
# .\Consumer_Discretionary\LennarCorporationLEN\LEN Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LennarCorporationLEN\LEN Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LennarCorporationLEN\LEN Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LennarCorporationLEN\len_historical_quotes.xlsx
# .\Consumer_Discretionary\LKQCorporationLKQ\LKQ Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LKQCorporationLKQ\LKQ Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LKQCorporationLKQ\LKQ Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\LKQCorporationLKQ\lkq_historical_quotes.xlsx
# .\Consumer_Discretionary\Lowe's Companies (LOW)\LOW Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Lowe's Companies (LOW)\LOW Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Lowe's Companies (LOW)\LOW Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\Lowe's Companies (LOW)\low_historical_quotes.xlsx
# .\Consumer_Discretionary\MarriottInternationalMAR\MAR Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\MarriottInternationalMAR\MAR Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\MarriottInternationalMAR\MAR Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\MarriottInternationalMAR\mar_historical_quotes.xlsx
# .\Consumer_Discretionary\McDonaldsCorporationMCD\MCD Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\McDonaldsCorporationMCD\MCD Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\McDonaldsCorporationMCD\MCD Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary\McDonaldsCorporationMCD\mcd_historical_quotes.xlsx
# .\Consumer_Discretionary\MGMResortsInternationalMGM\MGM Balance Sheet - Seeking Alpha.xlsx
# .\Consumer_Discretionary\MGMResortsInternationalMGM\MGM Cash Flow - Seeking Alpha.xlsx
# .\Consumer_Discretionary\MGMResortsInternationalMGM\MGM Income Statement - Seeking Alpha.xlsx
# .\Consumer_Discretionary
# .\Utilities\ExelonCorporationEXC\exc_historical_quotes.xlsx
# .\Utilities\FirstEnergyCorpFE\FE Balance Sheet - Seeking Alpha.xlsx
# .\Utilities\FirstEnergyCorpFE\FE Cash Flow - Seeking Alpha.xlsx
# .\Utilities\FirstEnergyCorpFE\FE Income Statement - Seeking Alpha.xlsx
# .\Utilities\FirstEnergyCorpFE\fe_historical_quotes.xlsx
# .\Utilities\NiSourceNI\NI Balance Sheet - Seeking Alpha.xlsx
# .\Utilities\NiSourceNI\NI Cash Flow - Seeking Alpha.xlsx
# .\Utilities\NiSourceNI\NI Income Statement - Seeking Alpha.xlsx
# .\Utilities\NiSourceNI\ni_historical_quotes.xlsx
# .\Utilities\NRGEnergyNRG\NRG Balance Sheet - Seeking Alpha.xlsx
# .\Utilities\NRGEnergyNRG\NRG Cash Flow - Seeking Alpha.xlsx
# .\Utilities\NRGEnergyNRG\NRG Income Statement - Seeking Alpha.xlsx
# .\Utilities\NRGEnergyNRG\nrg_historical_quotes.xlsx
# .\Utilities\PinnacleWestCapitalCorpPNW\PNW Balance Sheet - Seeking Alpha.xlsx
# .\Utilities\PinnacleWestCapitalCorpPNW\PNW Cash Flow - Seeking Alpha.xlsx
# .\Utilities\PinnacleWestCapitalCorpPNW\PNW Income Statement - Seeking Alpha.xlsx
# .\Utilities\PinnacleWestCapitalCorpPNW\pnw_historical_quotes.xlsx
# .\Utilities\PublicServiceEnterpriseGroupIncPEG\PEG Balance Sheet - Seeking Alpha.xlsx
# .\Utilities\PublicServiceEnterpriseGroupIncPEG\PEG Cash Flow - Seeking Alpha.xlsx
# .\Utilities\PublicServiceEnterpriseGroupIncPEG\PEG Income Statement - Seeking Alpha.xlsx
# .\Utilities\PublicServiceEnterpriseGroupIncPEG\peg_historical_quotes.xlsx
# 1219

# %%
os.listdir(path='.')
'''
    For the given path, get the List of all files in the directory tree 
'''
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles


counter = 0 
for file in getListOfFiles('.'):
    if file.endswith(".xlsx"):
        if file.find('Balance Sheet') != -1:
            #print(file)
            if file.find('Coca-Cola') != -1:
                #print(file)
                #balsheet_preprocessor(file)
                KO_BalSheet = pd.read_excel(file)
                KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
                KO_BalSheet = KO_BalSheet.iloc[1:]
                TKo_BalSheet = KO_BalSheet.transpose()
                TKo_BalSheet = TKo_BalSheet.rename(columns = TKo_BalSheet.iloc[0]) #Renaming columns
                Tko_BalSheet = TKo_BalSheet.iloc[1:]
                Tko_BalSheet = TKo_BalSheet.iloc[1:-1]
                Tko_BalSheet = Tko_BalSheet.loc[:, Tko_BalSheet.columns.notnull()] #Removing NaN columns
                Tko_BalSheet = Tko_BalSheet.dropna(axis = 1, how = 'all')

                # Removing all dollar signs ($) from dataframe
                # Tko_BalSheet.iloc[ : , i ] # Denoting column by index instead of name
                # https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
                for i in range(1, len(Tko_BalSheet.columns)):
                    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'\$':''}, regex = True)
                    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

                # Replacing dash values with 0
                for i in range(1, len(Tko_BalSheet.columns)):
                    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'-': 0}, regex = True)
                    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

                Tko_BalSheet_as_string = Tko_BalSheet.astype(str)

                # Denoting negative values with minus (-) instead of brackets ()
                for i in range(1, len(Tko_BalSheet_as_string.columns)):
                    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet_as_string.iloc[ : , i ].replace({'\(':'-', '\)':''}, regex = True)
# Out:
# .\Consumer\Coca-Cola\KO Balance Sheet - Seeking Alpha.xlsx
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~\Anaconda3\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'Cash And Equivalents' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-43-388068b4cc24> in <module>
#       6             if file.find('Coca-Cola') != -1:
#       7                 print(file)
# ----> 8                 balsheet_preprocessor(file)
#       9
#
# <ipython-input-37-101acaea02fe> in balsheet_preprocessor(filename)
#      38         Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet_as_string.iloc[ : , i ].replace({'\(':'-', '\)':''}, regex = True)
#      39
# ---> 40     Tko_BalSheet.to_sql('test_table', con= engine, if_exists='append', index = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     130
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#     134             context._rowcount = rowcount
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     232                 sql += b','
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#     236         return rows
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~\Anaconda3\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'Cash And Equivalents' in 'field list'")
# [SQL: INSERT INTO test_table (`Cash And Equivalents`, `Short Term Investments`, `Trading Asset Securities`, `Total Cash & ST Investments`, `Accounts Receivable`, `Total Receivables`, `Inventory`, `Prepaid Expenses`, `Deferred Tax Assets Current`, `Other Current Assets`, `Total Current Assets`, `Gross Property, Plant & Equipment`, `Accumulated Depreciation`, `Net Property, Plant & Equipment`, `Long-Term Investments`, `Goodwill`, `Other Intangibles`, `Deferred Tax Assets`, `Other Long-Term Assets`, `Total Assets`, `Accounts Payable`, `Accrued Expenses`, `Short-Term Borrowings`, `Current Portion of LT Debt`, `Current Income Taxes Payable`, `Other Current Liabilities`, `Total Current Liabilities`, `Long-Term Debt`, `Pension & Other Post-Retire. Benefits`, `Def. Tax Liability, Non-Curr.`, `Capital Leases`, `Other Non-Current Liabilities`, `Total Liabilities`, `Common Stock`, `Additional Paid In Capital`, `Retained Earnings`, `Treasury Stock`, `Comprehensive Income and Other`, `Total Common Equity`, `Minority Interest`, `Total Equity`, `Total Liabilities And Equity`, `Total Shares Out. on Filing Date`, `Total Common Shares Outstanding`, `Book Value / Share`, `Tangible Book Value`, `Tangible Book Value Per Share`, `Total Debt`, `Net Debt`, `Land`, `Buildings, Total`, `Machinery, Total`, `Full Time Employees`, `Total Employees`) VALUES (%(Cash And Equivalents)s, %(Short Term Investments)s, %(Trading Asset Securities)s, %(Total Cash & ST Investments)s, %(Accounts Receivable)s, %(Total Receivables)s, %(Inventory)s, %(Prepaid Expenses)s, %(Deferred Tax Assets Current)s, %(Other Current Assets)s, %(Total Current Assets)s, %(Gross Property, Plant & Equipment)s, %(Accumulated Depreciation)s, %(Net Property, Plant & Equipment)s, %(Long-Term Investments)s, %(Goodwill)s, %(Other Intangibles)s, %(Deferred Tax Assets)s, %(Other Long-Term Assets)s, %(Total Assets)s, %(Accounts Payable)s, %(Accrued Expenses)s, %(Short-Term Borrowings)s, %(Current Portion of LT Debt)s, %(Current Income Taxes Payable)s, %(Other Current Liabilities)s, %(Total Current Liabilities)s, %(Long-Term Debt)s, %(Pension & Other Post-Retire. Benefits)s, %(Def. Tax Liability, Non-Curr.)s, %(Capital Leases)s, %(Other Non-Current Liabilities)s, %(Total Liabilities)s, %(Common Stock)s, %(Additional Paid In Capital)s, %(Retained Earnings)s, %(Treasury Stock)s, %(Comprehensive Income and Other)s, %(Total Common Equity)s, %(Minority Interest)s, %(Total Equity)s, %(Total Liabilities And Equity)s, %(Total Shares Out. on Filing Date)s, %(Total Common Shares Outstanding)s, %(Book Value / Share)s, %(Tangible Book Value)s, %(Tangible Book Value Per Share)s, %(Total Debt)s, %(Net Debt)s, %(Land)s, %(Buildings, Total)s, %(Machinery, Total)s, %(Full Time Employees)s, %(Total Employees)s)]
# [parameters: ({'Cash And Equivalents': '8,517.0', 'Short Term Investments': '2,820.0', 'Trading Asset Securities': '0', 'Total Cash & ST Investments': '11,337.0', 'Accounts Receivable': '4,430.0', 'Total Receivables': '4,430.0', 'Inventory': '2,650.0', 'Prepaid Expenses': '2,205.0', 'Deferred Tax Assets Current': '478', 'Other Current Assets': '479', 'Total Current Assets': '21,579.0', 'Gross Property, Plant & Equipment': '21,706.0', 'Accumulated Depreciation': '-6,979.0', 'Net Property, Plant & Equipment': '14,727.0', 'Long-Term Investments': '7,662.0', 'Goodwill': '11,665.0', 'Other Intangibles': '15,244.0', 'Deferred Tax Assets': '98', 'Other Long-Term Assets': '1,946.0', 'Total Assets': '72,921.0', 'Accounts Payable': '1,887.0', 'Accrued Expenses': '6,639.0', 'Short-Term Borrowings': '8,100.0', 'Current Portion of LT Debt': '1,276.0', 'Current Income Taxes Payable': '273', 'Other Current Liabilities': '333', 'Total Current Liabilities': '18,508.0', 'Long-Term Debt': '14,138.0', 'Pension & Other Post-Retire. Benefits': '0', 'Def. Tax Liability, Non-Curr.': '4,261.0', 'Capital Leases': '0', 'Other Non-Current Liabilities': '4,697.0', 'Total Liabilities': '41,604.0', 'Common Stock': '880', 'Additional Paid In Capital': '10,057.0', 'Retained Earnings': '49,278.0', 'Treasury Stock': '-27,762.0', 'Comprehensive Income and Other': '-1,450.0', 'Total Common Equity': '31,003.0', 'Minority Interest': '314', 'Total Equity': '31,317.0', 'Total Liabilities And Equity': '72,921.0', 'Total Shares Out. on Filing Date': '4,588.6', 'Total Common Shares Outstanding': '4,584.0', 'Book Value / Share': '6.76', 'Tangible Book Value': '4,094.0', 'Tangible Book Value Per Share': '0.89', 'Total Debt': '23,514.0', 'Net Debt': '12,177.0', 'Land': '1,122.0', 'Buildings, Total': '4,883.0', 'Machinery, Total': '13,421.0', 'Full Time Employees': '139,600', 'Total Employees': '139,600'}, {'Cash And Equivalents': '12,803.0', 'Short Term Investments': '1,232.0', 'Trading Asset Securities': '0', 'Total Cash & ST Investments': '14,035.0', 'Accounts Receivable': '4,920.0', 'Total Receivables': '4,920.0', 'Inventory': '3,092.0', 'Prepaid Expenses': '2,614.0', 'Deferred Tax Assets Current': '227', 'Other Current Assets': '609', 'Total Current Assets': '25,497.0', 'Gross Property, Plant & Equipment': '23,151.0', 'Accumulated Depreciation': '-8,212.0', 'Net Property, Plant & Equipment': '14,939.0', 'Long-Term Investments': '8,693.0', 'Goodwill': '12,219.0', 'Other Intangibles': '15,450.0', 'Deferred Tax Assets': '243', 'Other Long-Term Assets': '2,933.0', 'Total Assets': '79,974.0', 'Accounts Payable': '2,172.0', 'Accrued Expenses': '6,488.0', 'Short-Term Borrowings': '12,871.0', 'Current Portion of LT Debt': '2,041.0', 'Current Income Taxes Payable': '362', 'Other Current Liabilities': '349', 'Total Current Liabilities': '24,283.0', 'Long-Term Debt': '13,656.0', 'Pension & Other Post-Retire. Benefits': '0', 'Def. Tax Liability, Non-Curr.': '4,694.0', 'Capital Leases': '0', 'Other Non-Current Liabilities': '5,420.0', 'Total Liabilities': '48,053.0', 'Common Stock': '1,760.0', 'Additional Paid In Capital': '10,332.0', 'Retained Earnings': '53,621.0', 'Treasury Stock': '-31,304.0', 'Comprehensive Income and Other': '-2,774.0', 'Total Common Equity': '31,635.0', 'Minority Interest': '286', 'Total Equity': '31,921.0', 'Total Liabilities And Equity': '79,974.0', 'Total Shares Out. on Filing Date': '4,526.4', 'Total Common Shares Outstanding': '4,526.0', 'Book Value / Share': '6.99', 'Tangible Book Value': '3,966.0', 'Tangible Book Value Per Share': '0.88', 'Total Debt': '28,568.0', 'Net Debt': '14,533.0', 'Land': '1,141.0', 'Buildings, Total': '5,240.0', 'Machinery, Total': '15,504.0', 'Full Time Employees': '146,200', 'Total Employees': '146,200'}, {'Cash And Equivalents': '8,442.0', 'Short Term Investments': '8,109.0', 'Trading Asset Securities': '7', 'Total Cash & ST Investments': '16,558.0', 'Accounts Receivable': '4,759.0', 'Total Receivables': '4,759.0', 'Invento ...
# (Background on this error at: http://sqlalche.me/e/2j85)
