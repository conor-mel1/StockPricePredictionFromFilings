# %%
import pandas as pd
import numpy as np
import re

KO_BalSheet = pd.read_excel("Coca-Cola\KO Balance Sheet - Seeking Alpha.xlsx")
KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
KO_BalSheet = KO_BalSheet.iloc[1:]
TKo_BalSheet = KO_BalSheet.transpose()
TKo_BalSheet = TKo_BalSheet.rename(columns = TKo_BalSheet.iloc[0]) #Renaming columns
Tko_BalSheet = TKo_BalSheet.iloc[1:]
Tko_BalSheet = TKo_BalSheet.iloc[1:-1]
Tko_BalSheet = Tko_BalSheet.loc[:, Tko_BalSheet.columns.notnull()] #Removing NaN columns
Tko_BalSheet = Tko_BalSheet.dropna(axis = 1, how = 'all')

# Removing all dollar signs ($) from dataframe
# Tko_BalSheet.iloc[ : , i ] # Denoting column by index instead of name
# https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'\$':''}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')
    
# Replacing dash values with 0
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'-': 0}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')
    
Tko_BalSheet_as_string = Tko_BalSheet.astype(str)

# Denoting negative values with minus (-) instead of brackets ()
for i in range(1, len(Tko_BalSheet_as_string.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet_as_string.iloc[ : , i ].replace({'\(':'-', '\)':''}, regex = True)
    
Tko_BalSheet
# Out:
#          Cash And Equivalents Short Term Investments Trading Asset Securities  \
# Dec 2010              8,517.0                2,820.0                        0
# Dec 2011             12,803.0                1,232.0                        0
# Dec 2012              8,442.0                8,109.0                        7
# Dec 2013             10,414.0                9,854.0                        0
# Dec 2014              8,958.0               12,717.0                       14
# Dec 2015              7,309.0               12,591.0                       20
# Dec 2016              8,555.0               13,646.0                        0
# Dec 2017              6,006.0               14,669.0                        0
# Dec 2018              9,077.0                7,038.0                        0
# Dec 2019              6,480.0                4,695.0                       10
#
#          Total Cash & ST Investments Accounts Receivable Total Receivables  \
# Dec 2010                    11,337.0             4,430.0           4,430.0
# Dec 2011                    14,035.0             4,920.0           4,920.0
# Dec 2012                    16,558.0             4,759.0           4,759.0
# Dec 2013                    20,268.0             4,873.0           4,873.0
# Dec 2014                    21,689.0             4,466.0           4,466.0
# Dec 2015                    19,920.0             3,941.0           3,941.0
# Dec 2016                    22,201.0             3,856.0           3,856.0
# Dec 2017                    20,675.0             3,667.0           3,667.0
# Dec 2018                    16,115.0             3,685.0           3,685.0
# Dec 2019                    11,185.0             3,971.0           3,971.0
#
#          Inventory Prepaid Expenses Deferred Tax Assets Current  \
# Dec 2010   2,650.0          2,205.0                         478
# Dec 2011   3,092.0          2,614.0                         227
# Dec 2012   3,264.0          1,989.0                         244
# Dec 2013   3,277.0          2,400.0                         211
# Dec 2014   3,100.0          1,902.0                         160
# Dec 2015   2,902.0          1,884.0                         151
# Dec 2016   2,675.0          1,686.0                          80
# Dec 2017   2,655.0          1,902.0                           0
# Dec 2018   3,071.0          1,946.0                           0
# Dec 2019   3,379.0          1,819.0                           0
#
#          Other Current Assets  ... Book Value / Share Tangible Book Value  \
# Dec 2010                  479  ...               6.76             4,094.0
# Dec 2011                  609  ...               6.99             3,966.0
# Dec 2012              3,514.0  ...               7.34             5,453.0
# Dec 2013                  275  ...               7.54             5,562.0
# Dec 2014              1,669.0  ...               6.94             3,948.0
# Dec 2015              4,597.0  ...               5.91             1,422.0
# Dec 2016              3,512.0  ...               5.38             1,934.0
# Dec 2017              7,646.0  ...               4.01                 436
# Dec 2018                  113  ...               3.98            -4,606.0
# Dec 2019                   57  ...               4.43            -7,785.0
#
#          Tangible Book Value Per Share Total Debt  Net Debt     Land  \
# Dec 2010                          0.89   23,514.0  12,177.0  1,122.0
# Dec 2011                          0.88   28,568.0  14,533.0  1,141.0
# Dec 2012                          1.22   32,616.0  16,058.0      997
# Dec 2013                          1.26   37,082.0  16,814.0  1,011.0
# Dec 2014                          0.90   41,782.0  20,093.0      972
# Dec 2015                          0.33   44,401.0  24,481.0      717
# Dec 2016                          0.45   45,757.0  23,556.0      589
# Dec 2017                          0.10   47,724.0  27,049.0      334
# Dec 2018                         -1.08   44,254.0  28,139.0      485
# Dec 2019                         -1.82   44,176.0  32,991.0      659
#
#          Buildings, Total Machinery, Total Full Time Employees Total Employees
# Dec 2010          4,883.0         13,421.0             139,600         139,600
# Dec 2011          5,240.0         15,504.0             146,200         146,200
# Dec 2012          5,307.0         16,203.0             150,900         150,900
# Dec 2013          5,605.0         17,551.0             130,600         130,600
# Dec 2014          5,541.0         18,745.0             129,200         129,200
# Dec 2015          4,914.0         16,723.0             123,200         123,200
# Dec 2016          4,574.0         16,093.0             100,300         100,300
# Dec 2017          3,917.0         12,198.0              61,800          61,800
# Dec 2018          4,322.0         12,804.0              62,600          62,600
# Dec 2019          4,576.0         13,686.0              86,200          86,200
#
# [10 rows x 54 columns]

# %%
import pandas as pd
import numpy as np
import re

# %%
KO_BalSheet = pd.read_excel("Coca-Cola\KO Balance Sheet - Seeking Alpha.xlsx")
KO_BalSheet
# Out:
#    In Millions of USD except per share items  Unnamed: 1  Unnamed: 2  \
# 0                              Balance Sheet    Dec 2010    Dec 2011
# 1              Cash & Short Term Investments         NaN         NaN
# 2                       Cash And Equivalents     8,517.0    12,803.0
# 3                     Short Term Investments     2,820.0     1,232.0
# 4                   Trading Asset Securities           -           -
# 5                Total Cash & ST Investments    11,337.0    14,035.0
# 6                                        NaN         NaN         NaN
# 7                                Receivables         NaN         NaN
# 8                        Accounts Receivable     4,430.0     4,920.0
# 9                          Total Receivables     4,430.0     4,920.0
# 10                                       NaN         NaN         NaN
# 11                            Current Assets         NaN         NaN
# 12                                 Inventory     2,650.0     3,092.0
# 13                          Prepaid Expenses     2,205.0     2,614.0
# 14               Deferred Tax Assets Current         478         227
# 15                      Other Current Assets         479         609
# 16                      Total Current Assets    21,579.0    25,497.0
# 17                                       NaN         NaN         NaN
# 18                          Long-Term Assets         NaN         NaN
# 19         Gross Property, Plant & Equipment    21,706.0    23,151.0
# 20                  Accumulated Depreciation   (6,979.0)   (8,212.0)
# 21           Net Property, Plant & Equipment    14,727.0    14,939.0
# 22                     Long-Term Investments     7,662.0     8,693.0
# 23                                  Goodwill    11,665.0    12,219.0
# 24                         Other Intangibles    15,244.0    15,450.0
# 25                       Deferred Tax Assets          98         243
# 26                    Other Long-Term Assets     1,946.0     2,933.0
# 27                              Total Assets    72,921.0    79,974.0
# 28                                       NaN         NaN         NaN
# 29                       Current Liabilities         NaN         NaN
# ..                                       ...         ...         ...
# 44                         Total Liabilities    41,604.0    48,053.0
# 45                                       NaN         NaN         NaN
# 46                             Common Equity         NaN         NaN
# 47                              Common Stock         880     1,760.0
# 48                Additional Paid In Capital    10,057.0    10,332.0
# 49                         Retained Earnings    49,278.0    53,621.0
# 50                            Treasury Stock  (27,762.0)  (31,304.0)
# 51            Comprehensive Income and Other   (1,450.0)   (2,774.0)
# 52                       Total Common Equity    31,003.0    31,635.0
# 53                                       NaN         NaN         NaN
# 54                      Stockholders' Equity         NaN         NaN
# 55                         Minority Interest         314         286
# 56                              Total Equity    31,317.0    31,921.0
# 57                                       NaN         NaN         NaN
# 58                      Liabilities & Equity         NaN         NaN
# 59              Total Liabilities And Equity    72,921.0    79,974.0
# 60                                       NaN         NaN         NaN
# 61                        Supplemental Items         NaN         NaN
# 62          Total Shares Out. on Filing Date     4,588.6     4,526.4
# 63           Total Common Shares Outstanding     4,584.0     4,526.0
# 64                        Book Value / Share       $6.76       $6.99
# 65                       Tangible Book Value     4,094.0     3,966.0
# 66             Tangible Book Value Per Share       $0.89       $0.88
# 67                                Total Debt    23,514.0    28,568.0
# 68                                  Net Debt    12,177.0    14,533.0
# 69                                      Land     1,122.0     1,141.0
# 70                          Buildings, Total     4,883.0     5,240.0
# 71                          Machinery, Total    13,421.0    15,504.0
# 72                       Full Time Employees     139,600     146,200
# 73                           Total Employees     139,600     146,200
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0     Dec 2012    Dec 2013    Dec 2014    Dec 2015    Dec 2016    Dec 2017
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2      8,442.0    10,414.0     8,958.0     7,309.0     8,555.0     6,006.0
# 3      8,109.0     9,854.0    12,717.0    12,591.0    13,646.0    14,669.0
# 4            7           -          14          20           -           -
# 5     16,558.0    20,268.0    21,689.0    19,920.0    22,201.0    20,675.0
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8      4,759.0     4,873.0     4,466.0     3,941.0     3,856.0     3,667.0
# 9      4,759.0     4,873.0     4,466.0     3,941.0     3,856.0     3,667.0
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12     3,264.0     3,277.0     3,100.0     2,902.0     2,675.0     2,655.0
# 13     1,989.0     2,400.0     1,902.0     1,884.0     1,686.0     1,902.0
# 14         244         211         160         151          80           -
# 15     3,514.0         275     1,669.0     4,597.0     3,512.0     7,646.0
# 16    30,328.0    31,304.0    32,986.0    33,395.0    34,010.0    36,545.0
# 17         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 19    23,486.0    25,032.0    25,258.0    22,354.0    21,256.0    16,449.0
# 20   (9,010.0)  (10,065.0)  (10,625.0)   (9,783.0)  (10,621.0)   (8,246.0)
# 21    14,476.0    14,967.0    14,633.0    12,571.0    10,635.0     8,203.0
# 22    11,454.0    12,659.0    14,839.0    16,868.0    18,569.0    23,281.0
# 23    12,255.0    12,312.0    12,100.0    11,289.0    10,629.0     9,401.0
# 24    15,082.0    15,299.0    14,272.0    12,843.0    10,499.0     7,235.0
# 25         403         328         319         360         326         330
# 26     2,176.0     3,186.0     2,874.0     2,670.0     2,602.0     2,901.0
# 27    86,174.0    90,055.0    92,023.0    89,996.0    87,270.0    87,896.0
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 44    53,006.0    56,615.0    61,462.0    64,232.0    64,050.0    68,919.0
# 45         NaN         NaN         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN         NaN
# 47     1,760.0     1,760.0     1,760.0     1,760.0     1,760.0     1,760.0
# 48    11,379.0    12,276.0    13,154.0    14,016.0    14,993.0    15,864.0
# 49    58,045.0    61,660.0    63,408.0    65,018.0    65,502.0    60,430.0
# 50  (35,009.0)  (39,091.0)  (42,225.0)  (45,066.0)  (47,988.0)  (50,677.0)
# 51   (3,385.0)   (3,432.0)   (5,777.0)  (10,174.0)  (11,205.0)  (10,305.0)
# 52    32,790.0    33,173.0    30,320.0    25,554.0    23,062.0    17,072.0
# 53         NaN         NaN         NaN         NaN         NaN         NaN
# 54         NaN         NaN         NaN         NaN         NaN         NaN
# 55         378         267         241         210         158     1,905.0
# 56    33,168.0    33,440.0    30,561.0    25,764.0    23,220.0    18,977.0
# 57         NaN         NaN         NaN         NaN         NaN         NaN
# 58         NaN         NaN         NaN         NaN         NaN         NaN
# 59    86,174.0    90,055.0    92,023.0    89,996.0    87,270.0    87,896.0
# 60         NaN         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN         NaN
# 62     4,456.7     4,405.9     4,366.2     4,329.5     4,293.5     4,265.9
# 63     4,469.0     4,402.0     4,366.0     4,324.0     4,288.0     4,259.0
# 64       $7.34       $7.54       $6.94       $5.91       $5.38       $4.01
# 65     5,453.0     5,562.0     3,948.0     1,422.0     1,934.0         436
# 66       $1.22       $1.26       $0.90       $0.33       $0.45       $0.10
# 67    32,616.0    37,082.0    41,782.0    44,401.0    45,757.0    47,724.0
# 68    16,058.0    16,814.0    20,093.0    24,481.0    23,556.0    27,049.0
# 69         997     1,011.0         972         717         589         334
# 70     5,307.0     5,605.0     5,541.0     4,914.0     4,574.0     3,917.0
# 71    16,203.0    17,551.0    18,745.0    16,723.0    16,093.0    12,198.0
# 72     150,900     130,600     129,200     123,200     100,300      61,800
# 73     150,900     130,600     129,200     123,200     100,300      61,800
#
#     Unnamed: 9 Unnamed: 10  Unnamed: 11
# 0     Dec 2018    Dec 2019  Last Report
# 1          NaN         NaN          NaN
# 2      9,077.0     6,480.0     13,561.0
# 3      7,038.0     4,695.0      4,105.0
# 4            -          10           12
# 5     16,115.0    11,185.0     17,678.0
# 6          NaN         NaN          NaN
# 7          NaN         NaN          NaN
# 8      3,685.0     3,971.0      4,430.0
# 9      3,685.0     3,971.0      4,430.0
# 10         NaN         NaN          NaN
# 11         NaN         NaN          NaN
# 12     3,071.0     3,379.0      3,558.0
# 13     1,946.0     1,819.0      2,339.0
# 14           -           -            -
# 15         113          57          229
# 16    24,930.0    20,411.0     28,234.0
# 17         NaN         NaN          NaN
# 18         NaN         NaN          NaN
# 19    17,611.0    20,293.0     19,278.0
# 20   (8,013.0)   (8,083.0)    (8,285.0)
# 21     9,598.0    12,210.0     10,993.0
# 22    21,538.0    21,730.0     20,354.0
# 23    14,109.0    16,764.0     16,673.0
# 24     7,478.0    10,002.0     11,165.0
# 25     2,674.0     2,412.0      2,275.0
# 26     2,889.0     2,852.0      4,319.0
# 27    83,216.0    86,381.0     94,013.0
# 28         NaN         NaN          NaN
# 29         NaN         NaN          NaN
# ..         ...         ...          ...
# 44    64,158.0    65,283.0     74,179.0
# 45         NaN         NaN          NaN
# 46         NaN         NaN          NaN
# 47     1,760.0     1,760.0      1,760.0
# 48    16,520.0    17,154.0     17,312.0
# 49    63,234.0    65,855.0     66,870.0
# 50  (51,719.0)  (52,244.0)   (52,088.0)
# 51  (12,814.0)  (13,544.0)   (15,696.0)
# 52    16,981.0    18,981.0     18,158.0
# 53         NaN         NaN          NaN
# 54         NaN         NaN          NaN
# 55     2,077.0     2,117.0      1,676.0
# 56    19,058.0    21,098.0     19,834.0
# 57         NaN         NaN          NaN
# 58         NaN         NaN          NaN
# 59    83,216.0    86,381.0     94,013.0
# 60         NaN         NaN          NaN
# 61         NaN         NaN          NaN
# 62     4,275.3     4,290.3      4,294.9
# 63     4,268.0     4,280.0      4,294.0
# 64       $3.98       $4.43        $4.23
# 65   (4,606.0)   (7,785.0)    (9,680.0)
# 66     ($1.08)     ($1.82)      ($2.25)
# 67    44,254.0    44,176.0     50,416.0
# 68    28,139.0    32,991.0     32,738.0
# 69         485         659            -
# 70     4,322.0     4,576.0            -
# 71    12,804.0    13,686.0            -
# 72      62,600      86,200            -
# 73      62,600      86,200            -
#
# [74 rows x 12 columns]

# %%
KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
KO_BalSheet
# Out:
#                         Balance Sheet    Dec 2010    Dec 2011    Dec 2012  \
# 0                       Balance Sheet    Dec 2010    Dec 2011    Dec 2012
# 1       Cash & Short Term Investments         NaN         NaN         NaN
# 2                Cash And Equivalents     8,517.0    12,803.0     8,442.0
# 3              Short Term Investments     2,820.0     1,232.0     8,109.0
# 4            Trading Asset Securities           -           -           7
# 5         Total Cash & ST Investments    11,337.0    14,035.0    16,558.0
# 6                                 NaN         NaN         NaN         NaN
# 7                         Receivables         NaN         NaN         NaN
# 8                 Accounts Receivable     4,430.0     4,920.0     4,759.0
# 9                   Total Receivables     4,430.0     4,920.0     4,759.0
# 10                                NaN         NaN         NaN         NaN
# 11                     Current Assets         NaN         NaN         NaN
# 12                          Inventory     2,650.0     3,092.0     3,264.0
# 13                   Prepaid Expenses     2,205.0     2,614.0     1,989.0
# 14        Deferred Tax Assets Current         478         227         244
# 15               Other Current Assets         479         609     3,514.0
# 16               Total Current Assets    21,579.0    25,497.0    30,328.0
# 17                                NaN         NaN         NaN         NaN
# 18                   Long-Term Assets         NaN         NaN         NaN
# 19  Gross Property, Plant & Equipment    21,706.0    23,151.0    23,486.0
# 20           Accumulated Depreciation   (6,979.0)   (8,212.0)   (9,010.0)
# 21    Net Property, Plant & Equipment    14,727.0    14,939.0    14,476.0
# 22              Long-Term Investments     7,662.0     8,693.0    11,454.0
# 23                           Goodwill    11,665.0    12,219.0    12,255.0
# 24                  Other Intangibles    15,244.0    15,450.0    15,082.0
# 25                Deferred Tax Assets          98         243         403
# 26             Other Long-Term Assets     1,946.0     2,933.0     2,176.0
# 27                       Total Assets    72,921.0    79,974.0    86,174.0
# 28                                NaN         NaN         NaN         NaN
# 29                Current Liabilities         NaN         NaN         NaN
# ..                                ...         ...         ...         ...
# 44                  Total Liabilities    41,604.0    48,053.0    53,006.0
# 45                                NaN         NaN         NaN         NaN
# 46                      Common Equity         NaN         NaN         NaN
# 47                       Common Stock         880     1,760.0     1,760.0
# 48         Additional Paid In Capital    10,057.0    10,332.0    11,379.0
# 49                  Retained Earnings    49,278.0    53,621.0    58,045.0
# 50                     Treasury Stock  (27,762.0)  (31,304.0)  (35,009.0)
# 51     Comprehensive Income and Other   (1,450.0)   (2,774.0)   (3,385.0)
# 52                Total Common Equity    31,003.0    31,635.0    32,790.0
# 53                                NaN         NaN         NaN         NaN
# 54               Stockholders' Equity         NaN         NaN         NaN
# 55                  Minority Interest         314         286         378
# 56                       Total Equity    31,317.0    31,921.0    33,168.0
# 57                                NaN         NaN         NaN         NaN
# 58               Liabilities & Equity         NaN         NaN         NaN
# 59       Total Liabilities And Equity    72,921.0    79,974.0    86,174.0
# 60                                NaN         NaN         NaN         NaN
# 61                 Supplemental Items         NaN         NaN         NaN
# 62   Total Shares Out. on Filing Date     4,588.6     4,526.4     4,456.7
# 63    Total Common Shares Outstanding     4,584.0     4,526.0     4,469.0
# 64                 Book Value / Share       $6.76       $6.99       $7.34
# 65                Tangible Book Value     4,094.0     3,966.0     5,453.0
# 66      Tangible Book Value Per Share       $0.89       $0.88       $1.22
# 67                         Total Debt    23,514.0    28,568.0    32,616.0
# 68                           Net Debt    12,177.0    14,533.0    16,058.0
# 69                               Land     1,122.0     1,141.0         997
# 70                   Buildings, Total     4,883.0     5,240.0     5,307.0
# 71                   Machinery, Total    13,421.0    15,504.0    16,203.0
# 72                Full Time Employees     139,600     146,200     150,900
# 73                    Total Employees     139,600     146,200     150,900
#
#       Dec 2013    Dec 2014    Dec 2015    Dec 2016    Dec 2017    Dec 2018  \
# 0     Dec 2013    Dec 2014    Dec 2015    Dec 2016    Dec 2017    Dec 2018
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2     10,414.0     8,958.0     7,309.0     8,555.0     6,006.0     9,077.0
# 3      9,854.0    12,717.0    12,591.0    13,646.0    14,669.0     7,038.0
# 4            -          14          20           -           -           -
# 5     20,268.0    21,689.0    19,920.0    22,201.0    20,675.0    16,115.0
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8      4,873.0     4,466.0     3,941.0     3,856.0     3,667.0     3,685.0
# 9      4,873.0     4,466.0     3,941.0     3,856.0     3,667.0     3,685.0
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12     3,277.0     3,100.0     2,902.0     2,675.0     2,655.0     3,071.0
# 13     2,400.0     1,902.0     1,884.0     1,686.0     1,902.0     1,946.0
# 14         211         160         151          80           -           -
# 15         275     1,669.0     4,597.0     3,512.0     7,646.0         113
# 16    31,304.0    32,986.0    33,395.0    34,010.0    36,545.0    24,930.0
# 17         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 19    25,032.0    25,258.0    22,354.0    21,256.0    16,449.0    17,611.0
# 20  (10,065.0)  (10,625.0)   (9,783.0)  (10,621.0)   (8,246.0)   (8,013.0)
# 21    14,967.0    14,633.0    12,571.0    10,635.0     8,203.0     9,598.0
# 22    12,659.0    14,839.0    16,868.0    18,569.0    23,281.0    21,538.0
# 23    12,312.0    12,100.0    11,289.0    10,629.0     9,401.0    14,109.0
# 24    15,299.0    14,272.0    12,843.0    10,499.0     7,235.0     7,478.0
# 25         328         319         360         326         330     2,674.0
# 26     3,186.0     2,874.0     2,670.0     2,602.0     2,901.0     2,889.0
# 27    90,055.0    92,023.0    89,996.0    87,270.0    87,896.0    83,216.0
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 44    56,615.0    61,462.0    64,232.0    64,050.0    68,919.0    64,158.0
# 45         NaN         NaN         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN         NaN
# 47     1,760.0     1,760.0     1,760.0     1,760.0     1,760.0     1,760.0
# 48    12,276.0    13,154.0    14,016.0    14,993.0    15,864.0    16,520.0
# 49    61,660.0    63,408.0    65,018.0    65,502.0    60,430.0    63,234.0
# 50  (39,091.0)  (42,225.0)  (45,066.0)  (47,988.0)  (50,677.0)  (51,719.0)
# 51   (3,432.0)   (5,777.0)  (10,174.0)  (11,205.0)  (10,305.0)  (12,814.0)
# 52    33,173.0    30,320.0    25,554.0    23,062.0    17,072.0    16,981.0
# 53         NaN         NaN         NaN         NaN         NaN         NaN
# 54         NaN         NaN         NaN         NaN         NaN         NaN
# 55         267         241         210         158     1,905.0     2,077.0
# 56    33,440.0    30,561.0    25,764.0    23,220.0    18,977.0    19,058.0
# 57         NaN         NaN         NaN         NaN         NaN         NaN
# 58         NaN         NaN         NaN         NaN         NaN         NaN
# 59    90,055.0    92,023.0    89,996.0    87,270.0    87,896.0    83,216.0
# 60         NaN         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN         NaN
# 62     4,405.9     4,366.2     4,329.5     4,293.5     4,265.9     4,275.3
# 63     4,402.0     4,366.0     4,324.0     4,288.0     4,259.0     4,268.0
# 64       $7.54       $6.94       $5.91       $5.38       $4.01       $3.98
# 65     5,562.0     3,948.0     1,422.0     1,934.0         436   (4,606.0)
# 66       $1.26       $0.90       $0.33       $0.45       $0.10     ($1.08)
# 67    37,082.0    41,782.0    44,401.0    45,757.0    47,724.0    44,254.0
# 68    16,814.0    20,093.0    24,481.0    23,556.0    27,049.0    28,139.0
# 69     1,011.0         972         717         589         334         485
# 70     5,605.0     5,541.0     4,914.0     4,574.0     3,917.0     4,322.0
# 71    17,551.0    18,745.0    16,723.0    16,093.0    12,198.0    12,804.0
# 72     130,600     129,200     123,200     100,300      61,800      62,600
# 73     130,600     129,200     123,200     100,300      61,800      62,600
#
#       Dec 2019  Last Report
# 0     Dec 2019  Last Report
# 1          NaN          NaN
# 2      6,480.0     13,561.0
# 3      4,695.0      4,105.0
# 4           10           12
# 5     11,185.0     17,678.0
# 6          NaN          NaN
# 7          NaN          NaN
# 8      3,971.0      4,430.0
# 9      3,971.0      4,430.0
# 10         NaN          NaN
# 11         NaN          NaN
# 12     3,379.0      3,558.0
# 13     1,819.0      2,339.0
# 14           -            -
# 15          57          229
# 16    20,411.0     28,234.0
# 17         NaN          NaN
# 18         NaN          NaN
# 19    20,293.0     19,278.0
# 20   (8,083.0)    (8,285.0)
# 21    12,210.0     10,993.0
# 22    21,730.0     20,354.0
# 23    16,764.0     16,673.0
# 24    10,002.0     11,165.0
# 25     2,412.0      2,275.0
# 26     2,852.0      4,319.0
# 27    86,381.0     94,013.0
# 28         NaN          NaN
# 29         NaN          NaN
# ..         ...          ...
# 44    65,283.0     74,179.0
# 45         NaN          NaN
# 46         NaN          NaN
# 47     1,760.0      1,760.0
# 48    17,154.0     17,312.0
# 49    65,855.0     66,870.0
# 50  (52,244.0)   (52,088.0)
# 51  (13,544.0)   (15,696.0)
# 52    18,981.0     18,158.0
# 53         NaN          NaN
# 54         NaN          NaN
# 55     2,117.0      1,676.0
# 56    21,098.0     19,834.0
# 57         NaN          NaN
# 58         NaN          NaN
# 59    86,381.0     94,013.0
# 60         NaN          NaN
# 61         NaN          NaN
# 62     4,290.3      4,294.9
# 63     4,280.0      4,294.0
# 64       $4.43        $4.23
# 65   (7,785.0)    (9,680.0)
# 66     ($1.82)      ($2.25)
# 67    44,176.0     50,416.0
# 68    32,991.0     32,738.0
# 69         659            -
# 70     4,576.0            -
# 71    13,686.0            -
# 72      86,200            -
# 73      86,200            -
#
# [74 rows x 12 columns]

# %%
KO_BalSheet = KO_BalSheet.iloc[1:]
KO_BalSheet
# Out:
#                         Balance Sheet    Dec 2010    Dec 2011    Dec 2012  \
# 1       Cash & Short Term Investments         NaN         NaN         NaN
# 2                Cash And Equivalents     8,517.0    12,803.0     8,442.0
# 3              Short Term Investments     2,820.0     1,232.0     8,109.0
# 4            Trading Asset Securities           -           -           7
# 5         Total Cash & ST Investments    11,337.0    14,035.0    16,558.0
# 6                                 NaN         NaN         NaN         NaN
# 7                         Receivables         NaN         NaN         NaN
# 8                 Accounts Receivable     4,430.0     4,920.0     4,759.0
# 9                   Total Receivables     4,430.0     4,920.0     4,759.0
# 10                                NaN         NaN         NaN         NaN
# 11                     Current Assets         NaN         NaN         NaN
# 12                          Inventory     2,650.0     3,092.0     3,264.0
# 13                   Prepaid Expenses     2,205.0     2,614.0     1,989.0
# 14        Deferred Tax Assets Current         478         227         244
# 15               Other Current Assets         479         609     3,514.0
# 16               Total Current Assets    21,579.0    25,497.0    30,328.0
# 17                                NaN         NaN         NaN         NaN
# 18                   Long-Term Assets         NaN         NaN         NaN
# 19  Gross Property, Plant & Equipment    21,706.0    23,151.0    23,486.0
# 20           Accumulated Depreciation   (6,979.0)   (8,212.0)   (9,010.0)
# 21    Net Property, Plant & Equipment    14,727.0    14,939.0    14,476.0
# 22              Long-Term Investments     7,662.0     8,693.0    11,454.0
# 23                           Goodwill    11,665.0    12,219.0    12,255.0
# 24                  Other Intangibles    15,244.0    15,450.0    15,082.0
# 25                Deferred Tax Assets          98         243         403
# 26             Other Long-Term Assets     1,946.0     2,933.0     2,176.0
# 27                       Total Assets    72,921.0    79,974.0    86,174.0
# 28                                NaN         NaN         NaN         NaN
# 29                Current Liabilities         NaN         NaN         NaN
# 30                   Accounts Payable     1,887.0     2,172.0     1,969.0
# ..                                ...         ...         ...         ...
# 44                  Total Liabilities    41,604.0    48,053.0    53,006.0
# 45                                NaN         NaN         NaN         NaN
# 46                      Common Equity         NaN         NaN         NaN
# 47                       Common Stock         880     1,760.0     1,760.0
# 48         Additional Paid In Capital    10,057.0    10,332.0    11,379.0
# 49                  Retained Earnings    49,278.0    53,621.0    58,045.0
# 50                     Treasury Stock  (27,762.0)  (31,304.0)  (35,009.0)
# 51     Comprehensive Income and Other   (1,450.0)   (2,774.0)   (3,385.0)
# 52                Total Common Equity    31,003.0    31,635.0    32,790.0
# 53                                NaN         NaN         NaN         NaN
# 54               Stockholders' Equity         NaN         NaN         NaN
# 55                  Minority Interest         314         286         378
# 56                       Total Equity    31,317.0    31,921.0    33,168.0
# 57                                NaN         NaN         NaN         NaN
# 58               Liabilities & Equity         NaN         NaN         NaN
# 59       Total Liabilities And Equity    72,921.0    79,974.0    86,174.0
# 60                                NaN         NaN         NaN         NaN
# 61                 Supplemental Items         NaN         NaN         NaN
# 62   Total Shares Out. on Filing Date     4,588.6     4,526.4     4,456.7
# 63    Total Common Shares Outstanding     4,584.0     4,526.0     4,469.0
# 64                 Book Value / Share       $6.76       $6.99       $7.34
# 65                Tangible Book Value     4,094.0     3,966.0     5,453.0
# 66      Tangible Book Value Per Share       $0.89       $0.88       $1.22
# 67                         Total Debt    23,514.0    28,568.0    32,616.0
# 68                           Net Debt    12,177.0    14,533.0    16,058.0
# 69                               Land     1,122.0     1,141.0         997
# 70                   Buildings, Total     4,883.0     5,240.0     5,307.0
# 71                   Machinery, Total    13,421.0    15,504.0    16,203.0
# 72                Full Time Employees     139,600     146,200     150,900
# 73                    Total Employees     139,600     146,200     150,900
#
#       Dec 2013    Dec 2014    Dec 2015    Dec 2016    Dec 2017    Dec 2018  \
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2     10,414.0     8,958.0     7,309.0     8,555.0     6,006.0     9,077.0
# 3      9,854.0    12,717.0    12,591.0    13,646.0    14,669.0     7,038.0
# 4            -          14          20           -           -           -
# 5     20,268.0    21,689.0    19,920.0    22,201.0    20,675.0    16,115.0
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8      4,873.0     4,466.0     3,941.0     3,856.0     3,667.0     3,685.0
# 9      4,873.0     4,466.0     3,941.0     3,856.0     3,667.0     3,685.0
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
# 12     3,277.0     3,100.0     2,902.0     2,675.0     2,655.0     3,071.0
# 13     2,400.0     1,902.0     1,884.0     1,686.0     1,902.0     1,946.0
# 14         211         160         151          80           -           -
# 15         275     1,669.0     4,597.0     3,512.0     7,646.0         113
# 16    31,304.0    32,986.0    33,395.0    34,010.0    36,545.0    24,930.0
# 17         NaN         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN         NaN
# 19    25,032.0    25,258.0    22,354.0    21,256.0    16,449.0    17,611.0
# 20  (10,065.0)  (10,625.0)   (9,783.0)  (10,621.0)   (8,246.0)   (8,013.0)
# 21    14,967.0    14,633.0    12,571.0    10,635.0     8,203.0     9,598.0
# 22    12,659.0    14,839.0    16,868.0    18,569.0    23,281.0    21,538.0
# 23    12,312.0    12,100.0    11,289.0    10,629.0     9,401.0    14,109.0
# 24    15,299.0    14,272.0    12,843.0    10,499.0     7,235.0     7,478.0
# 25         328         319         360         326         330     2,674.0
# 26     3,186.0     2,874.0     2,670.0     2,602.0     2,901.0     2,889.0
# 27    90,055.0    92,023.0    89,996.0    87,270.0    87,896.0    83,216.0
# 28         NaN         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN         NaN
# 30     1,933.0     2,089.0     2,795.0     2,682.0     2,288.0     2,719.0
# ..         ...         ...         ...         ...         ...         ...
# 44    56,615.0    61,462.0    64,232.0    64,050.0    68,919.0    64,158.0
# 45         NaN         NaN         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN         NaN
# 47     1,760.0     1,760.0     1,760.0     1,760.0     1,760.0     1,760.0
# 48    12,276.0    13,154.0    14,016.0    14,993.0    15,864.0    16,520.0
# 49    61,660.0    63,408.0    65,018.0    65,502.0    60,430.0    63,234.0
# 50  (39,091.0)  (42,225.0)  (45,066.0)  (47,988.0)  (50,677.0)  (51,719.0)
# 51   (3,432.0)   (5,777.0)  (10,174.0)  (11,205.0)  (10,305.0)  (12,814.0)
# 52    33,173.0    30,320.0    25,554.0    23,062.0    17,072.0    16,981.0
# 53         NaN         NaN         NaN         NaN         NaN         NaN
# 54         NaN         NaN         NaN         NaN         NaN         NaN
# 55         267         241         210         158     1,905.0     2,077.0
# 56    33,440.0    30,561.0    25,764.0    23,220.0    18,977.0    19,058.0
# 57         NaN         NaN         NaN         NaN         NaN         NaN
# 58         NaN         NaN         NaN         NaN         NaN         NaN
# 59    90,055.0    92,023.0    89,996.0    87,270.0    87,896.0    83,216.0
# 60         NaN         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN         NaN
# 62     4,405.9     4,366.2     4,329.5     4,293.5     4,265.9     4,275.3
# 63     4,402.0     4,366.0     4,324.0     4,288.0     4,259.0     4,268.0
# 64       $7.54       $6.94       $5.91       $5.38       $4.01       $3.98
# 65     5,562.0     3,948.0     1,422.0     1,934.0         436   (4,606.0)
# 66       $1.26       $0.90       $0.33       $0.45       $0.10     ($1.08)
# 67    37,082.0    41,782.0    44,401.0    45,757.0    47,724.0    44,254.0
# 68    16,814.0    20,093.0    24,481.0    23,556.0    27,049.0    28,139.0
# 69     1,011.0         972         717         589         334         485
# 70     5,605.0     5,541.0     4,914.0     4,574.0     3,917.0     4,322.0
# 71    17,551.0    18,745.0    16,723.0    16,093.0    12,198.0    12,804.0
# 72     130,600     129,200     123,200     100,300      61,800      62,600
# 73     130,600     129,200     123,200     100,300      61,800      62,600
#
#       Dec 2019 Last Report
# 1          NaN         NaN
# 2      6,480.0    13,561.0
# 3      4,695.0     4,105.0
# 4           10          12
# 5     11,185.0    17,678.0
# 6          NaN         NaN
# 7          NaN         NaN
# 8      3,971.0     4,430.0
# 9      3,971.0     4,430.0
# 10         NaN         NaN
# 11         NaN         NaN
# 12     3,379.0     3,558.0
# 13     1,819.0     2,339.0
# 14           -           -
# 15          57         229
# 16    20,411.0    28,234.0
# 17         NaN         NaN
# 18         NaN         NaN
# 19    20,293.0    19,278.0
# 20   (8,083.0)   (8,285.0)
# 21    12,210.0    10,993.0
# 22    21,730.0    20,354.0
# 23    16,764.0    16,673.0
# 24    10,002.0    11,165.0
# 25     2,412.0     2,275.0
# 26     2,852.0     4,319.0
# 27    86,381.0    94,013.0
# 28         NaN         NaN
# 29         NaN         NaN
# 30     3,804.0    12,312.0
# ..         ...         ...
# 44    65,283.0    74,179.0
# 45         NaN         NaN
# 46         NaN         NaN
# 47     1,760.0     1,760.0
# 48    17,154.0    17,312.0
# 49    65,855.0    66,870.0
# 50  (52,244.0)  (52,088.0)
# 51  (13,544.0)  (15,696.0)
# 52    18,981.0    18,158.0
# 53         NaN         NaN
# 54         NaN         NaN
# 55     2,117.0     1,676.0
# 56    21,098.0    19,834.0
# 57         NaN         NaN
# 58         NaN         NaN
# 59    86,381.0    94,013.0
# 60         NaN         NaN
# 61         NaN         NaN
# 62     4,290.3     4,294.9
# 63     4,280.0     4,294.0
# 64       $4.43       $4.23
# 65   (7,785.0)   (9,680.0)
# 66     ($1.82)     ($2.25)
# 67    44,176.0    50,416.0
# 68    32,991.0    32,738.0
# 69         659           -
# 70     4,576.0           -
# 71    13,686.0           -
# 72      86,200           -
# 73      86,200           -
#
# [73 rows x 12 columns]

# %%
TKo_BalSheet = KO_BalSheet.transpose()
TKo_BalSheet
# Out:
#                                           1                     2   \
# Balance Sheet  Cash & Short Term Investments  Cash And Equivalents
# Dec 2010                                 NaN               8,517.0
# Dec 2011                                 NaN              12,803.0
# Dec 2012                                 NaN               8,442.0
# Dec 2013                                 NaN              10,414.0
# Dec 2014                                 NaN               8,958.0
# Dec 2015                                 NaN               7,309.0
# Dec 2016                                 NaN               8,555.0
# Dec 2017                                 NaN               6,006.0
# Dec 2018                                 NaN               9,077.0
# Dec 2019                                 NaN               6,480.0
# Last Report                              NaN              13,561.0
#
#                                    3                         4   \
# Balance Sheet  Short Term Investments  Trading Asset Securities
# Dec 2010                      2,820.0                         -
# Dec 2011                      1,232.0                         -
# Dec 2012                      8,109.0                         7
# Dec 2013                      9,854.0                         -
# Dec 2014                     12,717.0                        14
# Dec 2015                     12,591.0                        20
# Dec 2016                     13,646.0                         -
# Dec 2017                     14,669.0                         -
# Dec 2018                      7,038.0                         -
# Dec 2019                      4,695.0                        10
# Last Report                   4,105.0                        12
#
#                                         5    6            7   \
# Balance Sheet  Total Cash & ST Investments  NaN  Receivables
# Dec 2010                          11,337.0  NaN          NaN
# Dec 2011                          14,035.0  NaN          NaN
# Dec 2012                          16,558.0  NaN          NaN
# Dec 2013                          20,268.0  NaN          NaN
# Dec 2014                          21,689.0  NaN          NaN
# Dec 2015                          19,920.0  NaN          NaN
# Dec 2016                          22,201.0  NaN          NaN
# Dec 2017                          20,675.0  NaN          NaN
# Dec 2018                          16,115.0  NaN          NaN
# Dec 2019                          11,185.0  NaN          NaN
# Last Report                       17,678.0  NaN          NaN
#
#                                 8                  9    10  ...  \
# Balance Sheet  Accounts Receivable  Total Receivables  NaN  ...
# Dec 2010                   4,430.0            4,430.0  NaN  ...
# Dec 2011                   4,920.0            4,920.0  NaN  ...
# Dec 2012                   4,759.0            4,759.0  NaN  ...
# Dec 2013                   4,873.0            4,873.0  NaN  ...
# Dec 2014                   4,466.0            4,466.0  NaN  ...
# Dec 2015                   3,941.0            3,941.0  NaN  ...
# Dec 2016                   3,856.0            3,856.0  NaN  ...
# Dec 2017                   3,667.0            3,667.0  NaN  ...
# Dec 2018                   3,685.0            3,685.0  NaN  ...
# Dec 2019                   3,971.0            3,971.0  NaN  ...
# Last Report                4,430.0            4,430.0  NaN  ...
#
#                                64                   65  \
# Balance Sheet  Book Value / Share  Tangible Book Value
# Dec 2010                    $6.76              4,094.0
# Dec 2011                    $6.99              3,966.0
# Dec 2012                    $7.34              5,453.0
# Dec 2013                    $7.54              5,562.0
# Dec 2014                    $6.94              3,948.0
# Dec 2015                    $5.91              1,422.0
# Dec 2016                    $5.38              1,934.0
# Dec 2017                    $4.01                  436
# Dec 2018                    $3.98            (4,606.0)
# Dec 2019                    $4.43            (7,785.0)
# Last Report                 $4.23            (9,680.0)
#
#                                           66          67        68       69  \
# Balance Sheet  Tangible Book Value Per Share  Total Debt  Net Debt     Land
# Dec 2010                               $0.89    23,514.0  12,177.0  1,122.0
# Dec 2011                               $0.88    28,568.0  14,533.0  1,141.0
# Dec 2012                               $1.22    32,616.0  16,058.0      997
# Dec 2013                               $1.26    37,082.0  16,814.0  1,011.0
# Dec 2014                               $0.90    41,782.0  20,093.0      972
# Dec 2015                               $0.33    44,401.0  24,481.0      717
# Dec 2016                               $0.45    45,757.0  23,556.0      589
# Dec 2017                               $0.10    47,724.0  27,049.0      334
# Dec 2018                             ($1.08)    44,254.0  28,139.0      485
# Dec 2019                             ($1.82)    44,176.0  32,991.0      659
# Last Report                          ($2.25)    50,416.0  32,738.0        -
#
#                              70                71                   72  \
# Balance Sheet  Buildings, Total  Machinery, Total  Full Time Employees
# Dec 2010                4,883.0          13,421.0              139,600
# Dec 2011                5,240.0          15,504.0              146,200
# Dec 2012                5,307.0          16,203.0              150,900
# Dec 2013                5,605.0          17,551.0              130,600
# Dec 2014                5,541.0          18,745.0              129,200
# Dec 2015                4,914.0          16,723.0              123,200
# Dec 2016                4,574.0          16,093.0              100,300
# Dec 2017                3,917.0          12,198.0               61,800
# Dec 2018                4,322.0          12,804.0               62,600
# Dec 2019                4,576.0          13,686.0               86,200
# Last Report                   -                 -                    -
#
#                             73
# Balance Sheet  Total Employees
# Dec 2010               139,600
# Dec 2011               146,200
# Dec 2012               150,900
# Dec 2013               130,600
# Dec 2014               129,200
# Dec 2015               123,200
# Dec 2016               100,300
# Dec 2017                61,800
# Dec 2018                62,600
# Dec 2019                86,200
# Last Report                  -
#
# [12 rows x 73 columns]

# %%
TKo_BalSheet['Time'] = TKo_BalSheet.index
TKo_BalSheet
# Out:
#                                            1                     2  \
# Balance Sheet  Cash & Short Term Investments  Cash And Equivalents
# Dec 2010                                 NaN               8,517.0
# Dec 2011                                 NaN              12,803.0
# Dec 2012                                 NaN               8,442.0
# Dec 2013                                 NaN              10,414.0
# Dec 2014                                 NaN               8,958.0
# Dec 2015                                 NaN               7,309.0
# Dec 2016                                 NaN               8,555.0
# Dec 2017                                 NaN               6,006.0
# Dec 2018                                 NaN               9,077.0
# Dec 2019                                 NaN               6,480.0
# Last Report                              NaN              13,561.0
#
#                                     3                         4  \
# Balance Sheet  Short Term Investments  Trading Asset Securities
# Dec 2010                      2,820.0                         -
# Dec 2011                      1,232.0                         -
# Dec 2012                      8,109.0                         7
# Dec 2013                      9,854.0                         -
# Dec 2014                     12,717.0                        14
# Dec 2015                     12,591.0                        20
# Dec 2016                     13,646.0                         -
# Dec 2017                     14,669.0                         -
# Dec 2018                      7,038.0                         -
# Dec 2019                      4,695.0                        10
# Last Report                   4,105.0                        12
#
#                                          5    6            7  \
# Balance Sheet  Total Cash & ST Investments  NaN  Receivables
# Dec 2010                          11,337.0  NaN          NaN
# Dec 2011                          14,035.0  NaN          NaN
# Dec 2012                          16,558.0  NaN          NaN
# Dec 2013                          20,268.0  NaN          NaN
# Dec 2014                          21,689.0  NaN          NaN
# Dec 2015                          19,920.0  NaN          NaN
# Dec 2016                          22,201.0  NaN          NaN
# Dec 2017                          20,675.0  NaN          NaN
# Dec 2018                          16,115.0  NaN          NaN
# Dec 2019                          11,185.0  NaN          NaN
# Last Report                       17,678.0  NaN          NaN
#
#                                  8                  9   10  ...  \
# Balance Sheet  Accounts Receivable  Total Receivables  NaN  ...
# Dec 2010                   4,430.0            4,430.0  NaN  ...
# Dec 2011                   4,920.0            4,920.0  NaN  ...
# Dec 2012                   4,759.0            4,759.0  NaN  ...
# Dec 2013                   4,873.0            4,873.0  NaN  ...
# Dec 2014                   4,466.0            4,466.0  NaN  ...
# Dec 2015                   3,941.0            3,941.0  NaN  ...
# Dec 2016                   3,856.0            3,856.0  NaN  ...
# Dec 2017                   3,667.0            3,667.0  NaN  ...
# Dec 2018                   3,685.0            3,685.0  NaN  ...
# Dec 2019                   3,971.0            3,971.0  NaN  ...
# Last Report                4,430.0            4,430.0  NaN  ...
#
#                                 65                             66          67  \
# Balance Sheet  Tangible Book Value  Tangible Book Value Per Share  Total Debt
# Dec 2010                   4,094.0                          $0.89    23,514.0
# Dec 2011                   3,966.0                          $0.88    28,568.0
# Dec 2012                   5,453.0                          $1.22    32,616.0
# Dec 2013                   5,562.0                          $1.26    37,082.0
# Dec 2014                   3,948.0                          $0.90    41,782.0
# Dec 2015                   1,422.0                          $0.33    44,401.0
# Dec 2016                   1,934.0                          $0.45    45,757.0
# Dec 2017                       436                          $0.10    47,724.0
# Dec 2018                 (4,606.0)                        ($1.08)    44,254.0
# Dec 2019                 (7,785.0)                        ($1.82)    44,176.0
# Last Report              (9,680.0)                        ($2.25)    50,416.0
#
#                      68       69                70                71  \
# Balance Sheet  Net Debt     Land  Buildings, Total  Machinery, Total
# Dec 2010       12,177.0  1,122.0           4,883.0          13,421.0
# Dec 2011       14,533.0  1,141.0           5,240.0          15,504.0
# Dec 2012       16,058.0      997           5,307.0          16,203.0
# Dec 2013       16,814.0  1,011.0           5,605.0          17,551.0
# Dec 2014       20,093.0      972           5,541.0          18,745.0
# Dec 2015       24,481.0      717           4,914.0          16,723.0
# Dec 2016       23,556.0      589           4,574.0          16,093.0
# Dec 2017       27,049.0      334           3,917.0          12,198.0
# Dec 2018       28,139.0      485           4,322.0          12,804.0
# Dec 2019       32,991.0      659           4,576.0          13,686.0
# Last Report    32,738.0        -                 -                 -
#
#                                 72               73           Time
# Balance Sheet  Full Time Employees  Total Employees  Balance Sheet
# Dec 2010                   139,600          139,600       Dec 2010
# Dec 2011                   146,200          146,200       Dec 2011
# Dec 2012                   150,900          150,900       Dec 2012
# Dec 2013                   130,600          130,600       Dec 2013
# Dec 2014                   129,200          129,200       Dec 2014
# Dec 2015                   123,200          123,200       Dec 2015
# Dec 2016                   100,300          100,300       Dec 2016
# Dec 2017                    61,800           61,800       Dec 2017
# Dec 2018                    62,600           62,600       Dec 2018
# Dec 2019                    86,200           86,200       Dec 2019
# Last Report                      -                -    Last Report
#
# [12 rows x 74 columns]

# %%
TKo_BalSheet = TKo_BalSheet.rename(columns = TKo_BalSheet.iloc[0]) #Renaming columns

# %%
Tko_BalSheet = TKo_BalSheet.iloc[1:]
Tko_BalSheet
# Out:
#             Cash & Short Term Investments Cash And Equivalents  \
# Dec 2010                              NaN              8,517.0
# Dec 2011                              NaN             12,803.0
# Dec 2012                              NaN              8,442.0
# Dec 2013                              NaN             10,414.0
# Dec 2014                              NaN              8,958.0
# Dec 2015                              NaN              7,309.0
# Dec 2016                              NaN              8,555.0
# Dec 2017                              NaN              6,006.0
# Dec 2018                              NaN              9,077.0
# Dec 2019                              NaN              6,480.0
# Last Report                           NaN             13,561.0
#
#             Short Term Investments Trading Asset Securities  \
# Dec 2010                   2,820.0                        -
# Dec 2011                   1,232.0                        -
# Dec 2012                   8,109.0                        7
# Dec 2013                   9,854.0                        -
# Dec 2014                  12,717.0                       14
# Dec 2015                  12,591.0                       20
# Dec 2016                  13,646.0                        -
# Dec 2017                  14,669.0                        -
# Dec 2018                   7,038.0                        -
# Dec 2019                   4,695.0                       10
# Last Report                4,105.0                       12
#
#             Total Cash & ST Investments  NaN Receivables Accounts Receivable  \
# Dec 2010                       11,337.0  NaN         NaN             4,430.0
# Dec 2011                       14,035.0  NaN         NaN             4,920.0
# Dec 2012                       16,558.0  NaN         NaN             4,759.0
# Dec 2013                       20,268.0  NaN         NaN             4,873.0
# Dec 2014                       21,689.0  NaN         NaN             4,466.0
# Dec 2015                       19,920.0  NaN         NaN             3,941.0
# Dec 2016                       22,201.0  NaN         NaN             3,856.0
# Dec 2017                       20,675.0  NaN         NaN             3,667.0
# Dec 2018                       16,115.0  NaN         NaN             3,685.0
# Dec 2019                       11,185.0  NaN         NaN             3,971.0
# Last Report                    17,678.0  NaN         NaN             4,430.0
#
#             Total Receivables  NaN  ... Tangible Book Value  \
# Dec 2010              4,430.0  NaN  ...             4,094.0
# Dec 2011              4,920.0  NaN  ...             3,966.0
# Dec 2012              4,759.0  NaN  ...             5,453.0
# Dec 2013              4,873.0  NaN  ...             5,562.0
# Dec 2014              4,466.0  NaN  ...             3,948.0
# Dec 2015              3,941.0  NaN  ...             1,422.0
# Dec 2016              3,856.0  NaN  ...             1,934.0
# Dec 2017              3,667.0  NaN  ...                 436
# Dec 2018              3,685.0  NaN  ...           (4,606.0)
# Dec 2019              3,971.0  NaN  ...           (7,785.0)
# Last Report           4,430.0  NaN  ...           (9,680.0)
#
#             Tangible Book Value Per Share Total Debt  Net Debt     Land  \
# Dec 2010                            $0.89   23,514.0  12,177.0  1,122.0
# Dec 2011                            $0.88   28,568.0  14,533.0  1,141.0
# Dec 2012                            $1.22   32,616.0  16,058.0      997
# Dec 2013                            $1.26   37,082.0  16,814.0  1,011.0
# Dec 2014                            $0.90   41,782.0  20,093.0      972
# Dec 2015                            $0.33   44,401.0  24,481.0      717
# Dec 2016                            $0.45   45,757.0  23,556.0      589
# Dec 2017                            $0.10   47,724.0  27,049.0      334
# Dec 2018                          ($1.08)   44,254.0  28,139.0      485
# Dec 2019                          ($1.82)   44,176.0  32,991.0      659
# Last Report                       ($2.25)   50,416.0  32,738.0        -
#
#             Buildings, Total Machinery, Total Full Time Employees  \
# Dec 2010             4,883.0         13,421.0             139,600
# Dec 2011             5,240.0         15,504.0             146,200
# Dec 2012             5,307.0         16,203.0             150,900
# Dec 2013             5,605.0         17,551.0             130,600
# Dec 2014             5,541.0         18,745.0             129,200
# Dec 2015             4,914.0         16,723.0             123,200
# Dec 2016             4,574.0         16,093.0             100,300
# Dec 2017             3,917.0         12,198.0              61,800
# Dec 2018             4,322.0         12,804.0              62,600
# Dec 2019             4,576.0         13,686.0              86,200
# Last Report                -                -                   -
#
#             Total Employees Balance Sheet
# Dec 2010            139,600      Dec 2010
# Dec 2011            146,200      Dec 2011
# Dec 2012            150,900      Dec 2012
# Dec 2013            130,600      Dec 2013
# Dec 2014            129,200      Dec 2014
# Dec 2015            123,200      Dec 2015
# Dec 2016            100,300      Dec 2016
# Dec 2017             61,800      Dec 2017
# Dec 2018             62,600      Dec 2018
# Dec 2019             86,200      Dec 2019
# Last Report               -   Last Report
#
# [11 rows x 74 columns]

# %%
Tko_BalSheet = TKo_BalSheet.iloc[1:-1]
Tko_BalSheet
# Out:
#          Cash & Short Term Investments Cash And Equivalents  \
# Dec 2010                           NaN              8,517.0
# Dec 2011                           NaN             12,803.0
# Dec 2012                           NaN              8,442.0
# Dec 2013                           NaN             10,414.0
# Dec 2014                           NaN              8,958.0
# Dec 2015                           NaN              7,309.0
# Dec 2016                           NaN              8,555.0
# Dec 2017                           NaN              6,006.0
# Dec 2018                           NaN              9,077.0
# Dec 2019                           NaN              6,480.0
#
#          Short Term Investments Trading Asset Securities  \
# Dec 2010                2,820.0                        -
# Dec 2011                1,232.0                        -
# Dec 2012                8,109.0                        7
# Dec 2013                9,854.0                        -
# Dec 2014               12,717.0                       14
# Dec 2015               12,591.0                       20
# Dec 2016               13,646.0                        -
# Dec 2017               14,669.0                        -
# Dec 2018                7,038.0                        -
# Dec 2019                4,695.0                       10
#
#          Total Cash & ST Investments  NaN Receivables Accounts Receivable  \
# Dec 2010                    11,337.0  NaN         NaN             4,430.0
# Dec 2011                    14,035.0  NaN         NaN             4,920.0
# Dec 2012                    16,558.0  NaN         NaN             4,759.0
# Dec 2013                    20,268.0  NaN         NaN             4,873.0
# Dec 2014                    21,689.0  NaN         NaN             4,466.0
# Dec 2015                    19,920.0  NaN         NaN             3,941.0
# Dec 2016                    22,201.0  NaN         NaN             3,856.0
# Dec 2017                    20,675.0  NaN         NaN             3,667.0
# Dec 2018                    16,115.0  NaN         NaN             3,685.0
# Dec 2019                    11,185.0  NaN         NaN             3,971.0
#
#          Total Receivables  NaN  ... Tangible Book Value  \
# Dec 2010           4,430.0  NaN  ...             4,094.0
# Dec 2011           4,920.0  NaN  ...             3,966.0
# Dec 2012           4,759.0  NaN  ...             5,453.0
# Dec 2013           4,873.0  NaN  ...             5,562.0
# Dec 2014           4,466.0  NaN  ...             3,948.0
# Dec 2015           3,941.0  NaN  ...             1,422.0
# Dec 2016           3,856.0  NaN  ...             1,934.0
# Dec 2017           3,667.0  NaN  ...                 436
# Dec 2018           3,685.0  NaN  ...           (4,606.0)
# Dec 2019           3,971.0  NaN  ...           (7,785.0)
#
#          Tangible Book Value Per Share Total Debt  Net Debt     Land  \
# Dec 2010                         $0.89   23,514.0  12,177.0  1,122.0
# Dec 2011                         $0.88   28,568.0  14,533.0  1,141.0
# Dec 2012                         $1.22   32,616.0  16,058.0      997
# Dec 2013                         $1.26   37,082.0  16,814.0  1,011.0
# Dec 2014                         $0.90   41,782.0  20,093.0      972
# Dec 2015                         $0.33   44,401.0  24,481.0      717
# Dec 2016                         $0.45   45,757.0  23,556.0      589
# Dec 2017                         $0.10   47,724.0  27,049.0      334
# Dec 2018                       ($1.08)   44,254.0  28,139.0      485
# Dec 2019                       ($1.82)   44,176.0  32,991.0      659
#
#          Buildings, Total Machinery, Total Full Time Employees  \
# Dec 2010          4,883.0         13,421.0             139,600
# Dec 2011          5,240.0         15,504.0             146,200
# Dec 2012          5,307.0         16,203.0             150,900
# Dec 2013          5,605.0         17,551.0             130,600
# Dec 2014          5,541.0         18,745.0             129,200
# Dec 2015          4,914.0         16,723.0             123,200
# Dec 2016          4,574.0         16,093.0             100,300
# Dec 2017          3,917.0         12,198.0              61,800
# Dec 2018          4,322.0         12,804.0              62,600
# Dec 2019          4,576.0         13,686.0              86,200
#
#          Total Employees Balance Sheet
# Dec 2010         139,600      Dec 2010
# Dec 2011         146,200      Dec 2011
# Dec 2012         150,900      Dec 2012
# Dec 2013         130,600      Dec 2013
# Dec 2014         129,200      Dec 2014
# Dec 2015         123,200      Dec 2015
# Dec 2016         100,300      Dec 2016
# Dec 2017          61,800      Dec 2017
# Dec 2018          62,600      Dec 2018
# Dec 2019          86,200      Dec 2019
#
# [10 rows x 74 columns]

# %%
Tko_BalSheet = Tko_BalSheet.loc[:, Tko_BalSheet.columns.notnull()] #Removing NaN columns
Tko_BalSheet
# Out:
#          Cash & Short Term Investments Cash And Equivalents  \
# Dec 2010                           NaN              8,517.0
# Dec 2011                           NaN             12,803.0
# Dec 2012                           NaN              8,442.0
# Dec 2013                           NaN             10,414.0
# Dec 2014                           NaN              8,958.0
# Dec 2015                           NaN              7,309.0
# Dec 2016                           NaN              8,555.0
# Dec 2017                           NaN              6,006.0
# Dec 2018                           NaN              9,077.0
# Dec 2019                           NaN              6,480.0
#
#          Short Term Investments Trading Asset Securities  \
# Dec 2010                2,820.0                        -
# Dec 2011                1,232.0                        -
# Dec 2012                8,109.0                        7
# Dec 2013                9,854.0                        -
# Dec 2014               12,717.0                       14
# Dec 2015               12,591.0                       20
# Dec 2016               13,646.0                        -
# Dec 2017               14,669.0                        -
# Dec 2018                7,038.0                        -
# Dec 2019                4,695.0                       10
#
#          Total Cash & ST Investments Receivables Accounts Receivable  \
# Dec 2010                    11,337.0         NaN             4,430.0
# Dec 2011                    14,035.0         NaN             4,920.0
# Dec 2012                    16,558.0         NaN             4,759.0
# Dec 2013                    20,268.0         NaN             4,873.0
# Dec 2014                    21,689.0         NaN             4,466.0
# Dec 2015                    19,920.0         NaN             3,941.0
# Dec 2016                    22,201.0         NaN             3,856.0
# Dec 2017                    20,675.0         NaN             3,667.0
# Dec 2018                    16,115.0         NaN             3,685.0
# Dec 2019                    11,185.0         NaN             3,971.0
#
#          Total Receivables Current Assets Inventory  ... Tangible Book Value  \
# Dec 2010           4,430.0            NaN   2,650.0  ...             4,094.0
# Dec 2011           4,920.0            NaN   3,092.0  ...             3,966.0
# Dec 2012           4,759.0            NaN   3,264.0  ...             5,453.0
# Dec 2013           4,873.0            NaN   3,277.0  ...             5,562.0
# Dec 2014           4,466.0            NaN   3,100.0  ...             3,948.0
# Dec 2015           3,941.0            NaN   2,902.0  ...             1,422.0
# Dec 2016           3,856.0            NaN   2,675.0  ...             1,934.0
# Dec 2017           3,667.0            NaN   2,655.0  ...                 436
# Dec 2018           3,685.0            NaN   3,071.0  ...           (4,606.0)
# Dec 2019           3,971.0            NaN   3,379.0  ...           (7,785.0)
#
#          Tangible Book Value Per Share Total Debt  Net Debt     Land  \
# Dec 2010                         $0.89   23,514.0  12,177.0  1,122.0
# Dec 2011                         $0.88   28,568.0  14,533.0  1,141.0
# Dec 2012                         $1.22   32,616.0  16,058.0      997
# Dec 2013                         $1.26   37,082.0  16,814.0  1,011.0
# Dec 2014                         $0.90   41,782.0  20,093.0      972
# Dec 2015                         $0.33   44,401.0  24,481.0      717
# Dec 2016                         $0.45   45,757.0  23,556.0      589
# Dec 2017                         $0.10   47,724.0  27,049.0      334
# Dec 2018                       ($1.08)   44,254.0  28,139.0      485
# Dec 2019                       ($1.82)   44,176.0  32,991.0      659
#
#          Buildings, Total Machinery, Total Full Time Employees  \
# Dec 2010          4,883.0         13,421.0             139,600
# Dec 2011          5,240.0         15,504.0             146,200
# Dec 2012          5,307.0         16,203.0             150,900
# Dec 2013          5,605.0         17,551.0             130,600
# Dec 2014          5,541.0         18,745.0             129,200
# Dec 2015          4,914.0         16,723.0             123,200
# Dec 2016          4,574.0         16,093.0             100,300
# Dec 2017          3,917.0         12,198.0              61,800
# Dec 2018          4,322.0         12,804.0              62,600
# Dec 2019          4,576.0         13,686.0              86,200
#
#          Total Employees Balance Sheet
# Dec 2010         139,600      Dec 2010
# Dec 2011         146,200      Dec 2011
# Dec 2012         150,900      Dec 2012
# Dec 2013         130,600      Dec 2013
# Dec 2014         129,200      Dec 2014
# Dec 2015         123,200      Dec 2015
# Dec 2016         100,300      Dec 2016
# Dec 2017          61,800      Dec 2017
# Dec 2018          62,600      Dec 2018
# Dec 2019          86,200      Dec 2019
#
# [10 rows x 65 columns]

# %%
Tko_BalSheet = Tko_BalSheet.dropna(axis = 1, how = 'all')
Tko_BalSheet
# Out:
#          Cash And Equivalents Short Term Investments Trading Asset Securities  \
# Dec 2010              8,517.0                2,820.0                        -
# Dec 2011             12,803.0                1,232.0                        -
# Dec 2012              8,442.0                8,109.0                        7
# Dec 2013             10,414.0                9,854.0                        -
# Dec 2014              8,958.0               12,717.0                       14
# Dec 2015              7,309.0               12,591.0                       20
# Dec 2016              8,555.0               13,646.0                        -
# Dec 2017              6,006.0               14,669.0                        -
# Dec 2018              9,077.0                7,038.0                        -
# Dec 2019              6,480.0                4,695.0                       10
#
#          Total Cash & ST Investments Accounts Receivable Total Receivables  \
# Dec 2010                    11,337.0             4,430.0           4,430.0
# Dec 2011                    14,035.0             4,920.0           4,920.0
# Dec 2012                    16,558.0             4,759.0           4,759.0
# Dec 2013                    20,268.0             4,873.0           4,873.0
# Dec 2014                    21,689.0             4,466.0           4,466.0
# Dec 2015                    19,920.0             3,941.0           3,941.0
# Dec 2016                    22,201.0             3,856.0           3,856.0
# Dec 2017                    20,675.0             3,667.0           3,667.0
# Dec 2018                    16,115.0             3,685.0           3,685.0
# Dec 2019                    11,185.0             3,971.0           3,971.0
#
#          Inventory Prepaid Expenses Deferred Tax Assets Current  \
# Dec 2010   2,650.0          2,205.0                         478
# Dec 2011   3,092.0          2,614.0                         227
# Dec 2012   3,264.0          1,989.0                         244
# Dec 2013   3,277.0          2,400.0                         211
# Dec 2014   3,100.0          1,902.0                         160
# Dec 2015   2,902.0          1,884.0                         151
# Dec 2016   2,675.0          1,686.0                          80
# Dec 2017   2,655.0          1,902.0                           -
# Dec 2018   3,071.0          1,946.0                           -
# Dec 2019   3,379.0          1,819.0                           -
#
#          Other Current Assets  ... Tangible Book Value  \
# Dec 2010                  479  ...             4,094.0
# Dec 2011                  609  ...             3,966.0
# Dec 2012              3,514.0  ...             5,453.0
# Dec 2013                  275  ...             5,562.0
# Dec 2014              1,669.0  ...             3,948.0
# Dec 2015              4,597.0  ...             1,422.0
# Dec 2016              3,512.0  ...             1,934.0
# Dec 2017              7,646.0  ...                 436
# Dec 2018                  113  ...           (4,606.0)
# Dec 2019                   57  ...           (7,785.0)
#
#          Tangible Book Value Per Share Total Debt  Net Debt     Land  \
# Dec 2010                         $0.89   23,514.0  12,177.0  1,122.0
# Dec 2011                         $0.88   28,568.0  14,533.0  1,141.0
# Dec 2012                         $1.22   32,616.0  16,058.0      997
# Dec 2013                         $1.26   37,082.0  16,814.0  1,011.0
# Dec 2014                         $0.90   41,782.0  20,093.0      972
# Dec 2015                         $0.33   44,401.0  24,481.0      717
# Dec 2016                         $0.45   45,757.0  23,556.0      589
# Dec 2017                         $0.10   47,724.0  27,049.0      334
# Dec 2018                       ($1.08)   44,254.0  28,139.0      485
# Dec 2019                       ($1.82)   44,176.0  32,991.0      659
#
#          Buildings, Total Machinery, Total Full Time Employees  \
# Dec 2010          4,883.0         13,421.0             139,600
# Dec 2011          5,240.0         15,504.0             146,200
# Dec 2012          5,307.0         16,203.0             150,900
# Dec 2013          5,605.0         17,551.0             130,600
# Dec 2014          5,541.0         18,745.0             129,200
# Dec 2015          4,914.0         16,723.0             123,200
# Dec 2016          4,574.0         16,093.0             100,300
# Dec 2017          3,917.0         12,198.0              61,800
# Dec 2018          4,322.0         12,804.0              62,600
# Dec 2019          4,576.0         13,686.0              86,200
#
#          Total Employees Balance Sheet
# Dec 2010         139,600      Dec 2010
# Dec 2011         146,200      Dec 2011
# Dec 2012         150,900      Dec 2012
# Dec 2013         130,600      Dec 2013
# Dec 2014         129,200      Dec 2014
# Dec 2015         123,200      Dec 2015
# Dec 2016         100,300      Dec 2016
# Dec 2017          61,800      Dec 2017
# Dec 2018          62,600      Dec 2018
# Dec 2019          86,200      Dec 2019
#
# [10 rows x 55 columns]

# %%
Tko_BalSheet = Tko_BalSheet.rename(columns = {"Balance Sheet": "Time"})

# %%
Tko_BalSheet
# Out:
#          Cash And Equivalents Short Term Investments Trading Asset Securities  \
# Dec 2010              8,517.0                2,820.0                        -
# Dec 2011             12,803.0                1,232.0                        -
# Dec 2012              8,442.0                8,109.0                        7
# Dec 2013             10,414.0                9,854.0                        -
# Dec 2014              8,958.0               12,717.0                       14
# Dec 2015              7,309.0               12,591.0                       20
# Dec 2016              8,555.0               13,646.0                        -
# Dec 2017              6,006.0               14,669.0                        -
# Dec 2018              9,077.0                7,038.0                        -
# Dec 2019              6,480.0                4,695.0                       10
#
#          Total Cash & ST Investments Accounts Receivable Total Receivables  \
# Dec 2010                    11,337.0             4,430.0           4,430.0
# Dec 2011                    14,035.0             4,920.0           4,920.0
# Dec 2012                    16,558.0             4,759.0           4,759.0
# Dec 2013                    20,268.0             4,873.0           4,873.0
# Dec 2014                    21,689.0             4,466.0           4,466.0
# Dec 2015                    19,920.0             3,941.0           3,941.0
# Dec 2016                    22,201.0             3,856.0           3,856.0
# Dec 2017                    20,675.0             3,667.0           3,667.0
# Dec 2018                    16,115.0             3,685.0           3,685.0
# Dec 2019                    11,185.0             3,971.0           3,971.0
#
#          Inventory Prepaid Expenses Deferred Tax Assets Current  \
# Dec 2010   2,650.0          2,205.0                         478
# Dec 2011   3,092.0          2,614.0                         227
# Dec 2012   3,264.0          1,989.0                         244
# Dec 2013   3,277.0          2,400.0                         211
# Dec 2014   3,100.0          1,902.0                         160
# Dec 2015   2,902.0          1,884.0                         151
# Dec 2016   2,675.0          1,686.0                          80
# Dec 2017   2,655.0          1,902.0                           -
# Dec 2018   3,071.0          1,946.0                           -
# Dec 2019   3,379.0          1,819.0                           -
#
#          Other Current Assets  ... Tangible Book Value  \
# Dec 2010                  479  ...             4,094.0
# Dec 2011                  609  ...             3,966.0
# Dec 2012              3,514.0  ...             5,453.0
# Dec 2013                  275  ...             5,562.0
# Dec 2014              1,669.0  ...             3,948.0
# Dec 2015              4,597.0  ...             1,422.0
# Dec 2016              3,512.0  ...             1,934.0
# Dec 2017              7,646.0  ...                 436
# Dec 2018                  113  ...           (4,606.0)
# Dec 2019                   57  ...           (7,785.0)
#
#          Tangible Book Value Per Share Total Debt  Net Debt     Land  \
# Dec 2010                         $0.89   23,514.0  12,177.0  1,122.0
# Dec 2011                         $0.88   28,568.0  14,533.0  1,141.0
# Dec 2012                         $1.22   32,616.0  16,058.0      997
# Dec 2013                         $1.26   37,082.0  16,814.0  1,011.0
# Dec 2014                         $0.90   41,782.0  20,093.0      972
# Dec 2015                         $0.33   44,401.0  24,481.0      717
# Dec 2016                         $0.45   45,757.0  23,556.0      589
# Dec 2017                         $0.10   47,724.0  27,049.0      334
# Dec 2018                       ($1.08)   44,254.0  28,139.0      485
# Dec 2019                       ($1.82)   44,176.0  32,991.0      659
#
#          Buildings, Total Machinery, Total Full Time Employees  \
# Dec 2010          4,883.0         13,421.0             139,600
# Dec 2011          5,240.0         15,504.0             146,200
# Dec 2012          5,307.0         16,203.0             150,900
# Dec 2013          5,605.0         17,551.0             130,600
# Dec 2014          5,541.0         18,745.0             129,200
# Dec 2015          4,914.0         16,723.0             123,200
# Dec 2016          4,574.0         16,093.0             100,300
# Dec 2017          3,917.0         12,198.0              61,800
# Dec 2018          4,322.0         12,804.0              62,600
# Dec 2019          4,576.0         13,686.0              86,200
#
#          Total Employees      Time
# Dec 2010         139,600  Dec 2010
# Dec 2011         146,200  Dec 2011
# Dec 2012         150,900  Dec 2012
# Dec 2013         130,600  Dec 2013
# Dec 2014         129,200  Dec 2014
# Dec 2015         123,200  Dec 2015
# Dec 2016         100,300  Dec 2016
# Dec 2017          61,800  Dec 2017
# Dec 2018          62,600  Dec 2018
# Dec 2019          86,200  Dec 2019
#
# [10 rows x 55 columns]

# %%
# Removing all dollar signs ($) from dataframe
# Tko_BalSheet.iloc[ : , i ] # Denoting column by index instead of name
# https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'\$':''}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

# %%
# Replacing dash values with 0
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'-': 0}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

# %%
Tko_BalSheet1 = Tko_BalSheet.astype(str)

# %%
# Denoting negative values with minus (-) instead of brackets ()
for i in range(1, len(Tko_BalSheet1.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet1.iloc[ : , i ].replace({'\(':'-', '\)':''}, regex = True)

# %%
Tko_BalSheet = Tko_BalSheet.reset_index(drop=True)

# %%
Tko_BalSheet
# Out:
#   Cash And Equivalents Short Term Investments Trading Asset Securities  \
# 0              8,517.0                2,820.0                        0
# 1             12,803.0                1,232.0                        0
# 2              8,442.0                8,109.0                        7
# 3             10,414.0                9,854.0                        0
# 4              8,958.0               12,717.0                       14
# 5              7,309.0               12,591.0                       20
# 6              8,555.0               13,646.0                        0
# 7              6,006.0               14,669.0                        0
# 8              9,077.0                7,038.0                        0
# 9              6,480.0                4,695.0                       10
#
#   Total Cash & ST Investments Accounts Receivable Total Receivables Inventory  \
# 0                    11,337.0             4,430.0           4,430.0   2,650.0
# 1                    14,035.0             4,920.0           4,920.0   3,092.0
# 2                    16,558.0             4,759.0           4,759.0   3,264.0
# 3                    20,268.0             4,873.0           4,873.0   3,277.0
# 4                    21,689.0             4,466.0           4,466.0   3,100.0
# 5                    19,920.0             3,941.0           3,941.0   2,902.0
# 6                    22,201.0             3,856.0           3,856.0   2,675.0
# 7                    20,675.0             3,667.0           3,667.0   2,655.0
# 8                    16,115.0             3,685.0           3,685.0   3,071.0
# 9                    11,185.0             3,971.0           3,971.0   3,379.0
#
#   Prepaid Expenses Deferred Tax Assets Current Other Current Assets  ...  \
# 0          2,205.0                         478                  479  ...
# 1          2,614.0                         227                  609  ...
# 2          1,989.0                         244              3,514.0  ...
# 3          2,400.0                         211                  275  ...
# 4          1,902.0                         160              1,669.0  ...
# 5          1,884.0                         151              4,597.0  ...
# 6          1,686.0                          80              3,512.0  ...
# 7          1,902.0                           0              7,646.0  ...
# 8          1,946.0                           0                  113  ...
# 9          1,819.0                           0                   57  ...
#
#   Tangible Book Value Tangible Book Value Per Share Total Debt  Net Debt  \
# 0             4,094.0                          0.89   23,514.0  12,177.0
# 1             3,966.0                          0.88   28,568.0  14,533.0
# 2             5,453.0                          1.22   32,616.0  16,058.0
# 3             5,562.0                          1.26   37,082.0  16,814.0
# 4             3,948.0                          0.90   41,782.0  20,093.0
# 5             1,422.0                          0.33   44,401.0  24,481.0
# 6             1,934.0                          0.45   45,757.0  23,556.0
# 7                 436                          0.10   47,724.0  27,049.0
# 8            -4,606.0                         -1.08   44,254.0  28,139.0
# 9            -7,785.0                         -1.82   44,176.0  32,991.0
#
#       Land Buildings, Total Machinery, Total Full Time Employees  \
# 0  1,122.0          4,883.0         13,421.0             139,600
# 1  1,141.0          5,240.0         15,504.0             146,200
# 2      997          5,307.0         16,203.0             150,900
# 3  1,011.0          5,605.0         17,551.0             130,600
# 4      972          5,541.0         18,745.0             129,200
# 5      717          4,914.0         16,723.0             123,200
# 6      589          4,574.0         16,093.0             100,300
# 7      334          3,917.0         12,198.0              61,800
# 8      485          4,322.0         12,804.0              62,600
# 9      659          4,576.0         13,686.0              86,200
#
#   Total Employees      Time
# 0         139,600  Dec 2010
# 1         146,200  Dec 2011
# 2         150,900  Dec 2012
# 3         130,600  Dec 2013
# 4         129,200  Dec 2014
# 5         123,200  Dec 2015
# 6         100,300  Dec 2016
# 7          61,800  Dec 2017
# 8          62,600  Dec 2018
# 9          86,200  Dec 2019
#
# [10 rows x 55 columns]

# %%
TKo_BalSheet['Time']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-5120be750524> in <module>
# ----> 1 TKo_BalSheet['Time']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# KeyError: 'Time'

# %%
for col in Tko_BalSheet.columns:
    print(col)

# %%
import pandas as pd
import numpy as np
import re

KO_BalSheet = pd.read_excel("Altria\MO Balance Sheet - Seeking Alpha.xlsx")
KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
KO_BalSheet = KO_BalSheet.iloc[1:]
TKo_BalSheet = KO_BalSheet.transpose()
TKo_BalSheet = TKo_BalSheet.rename(columns = TKo_BalSheet.iloc[0]) #Renaming columns
Tko_BalSheet = TKo_BalSheet.iloc[1:]
Tko_BalSheet = TKo_BalSheet.iloc[1:-1]
Tko_BalSheet = Tko_BalSheet.loc[:, Tko_BalSheet.columns.notnull()] #Removing NaN columns
Tko_BalSheet = Tko_BalSheet.dropna(axis = 1, how = 'all')

# Removing all dollar signs ($) from dataframe
# Tko_BalSheet.iloc[ : , i ] # Denoting column by index instead of name
# https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'\$':''}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')
    
# Replacing dash values with 0
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'-': 0}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')
    
Tko_BalSheet_as_string = Tko_BalSheet.astype(str)

# Denoting negative values with minus (-) instead of brackets ()
for i in range(1, len(Tko_BalSheet_as_string.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet_as_string.iloc[ : , i ].replace({'\(':'-', '\)':''}, regex = True)
    
Tko_BalSheet

# %%
import os
import pymysql
import pandas as pd
import numpy as np
import re
from pandas.io import sql
import MySQLdb
from sqlalchemy import create_engine

# %%
KO_BalSheet = pd.read_excel("Altria\MO Balance Sheet - Seeking Alpha.xlsx")
actual_filename = os.path.basename("Altria\MO Balance Sheet - Seeking Alpha.xlsx") # Getting filename from filepath
company_name = actual_filename.split(' ')[0] # Company Ticker Symbol
KO_BalSheet = KO_BalSheet.rename(columns = KO_BalSheet.iloc[0]) #Renaming columns
KO_BalSheet = KO_BalSheet.iloc[1:]
TKo_BalSheet = KO_BalSheet.transpose()
TKo_BalSheet = TKo_BalSheet.rename(columns = TKo_BalSheet.iloc[0]) #Renaming columns
Tko_BalSheet = TKo_BalSheet.iloc[1:-1]
Tko_BalSheet = Tko_BalSheet.loc[:, Tko_BalSheet.columns.notnull()] #Removing NaN columns
Tko_BalSheet = Tko_BalSheet.dropna(axis = 1, how = 'all')

# %%
# Removing all dollar signs ($) from dataframe
# Tko_BalSheet.iloc[ : , i ] # Denoting column by index instead of name
# https://stackoverflow.com/questions/43096522/remove-dollar-sign-from-entire-python-pandas-dataframe
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'\$':''}, regex = True)
    #Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].str.replace('$', '')

# Accounting for columns filled completely with - and removing these
for i in range(1, len(Tko_BalSheet)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace({'-': np.nan}, regex = True)
                    
Tko_BalSheet = Tko_BalSheet.dropna(how='all', axis=1)
                
for i in range(1, len(Tko_BalSheet.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet.iloc[ : , i ].replace(np.nan, 0, regex = True)
                
Tko_BalSheet_as_string = Tko_BalSheet.astype(str)

# Denoting negative values with minus (-) instead of brackets (), removing % sign
for i in range(1, len(Tko_BalSheet_as_string.columns)):
    Tko_BalSheet.iloc[ : , i ] = Tko_BalSheet_as_string.iloc[ : , i ].replace({'\(':'-', '\)':'', '%':''}, regex = True)
    
Tko_BalSheet

# %%
pd.io.parsers.ParserBase({'names':Tko_BalSheet.columns})._maybe_dedup_names(Tko_BalSheet.columns)
# Out:
# ['Cash And Equivalents',
#  'Short Term Investments',
#  'Trading Asset Securities',
#  'Total Cash & ST Investments',
#  'Accounts Receivable',
#  'Total Receivables',
#  'Inventory',
#  'Prepaid Expenses',
#  'Deferred Tax Assets Current',
#  'Other Current Assets',
#  'Total Current Assets',
#  'Gross Property, Plant & Equipment',
#  'Accumulated Depreciation',
#  'Net Property, Plant & Equipment',
#  'Long-Term Investments',
#  'Goodwill',
#  'Other Intangibles',
#  'Deferred Tax Assets',
#  'Other Long-Term Assets',
#  'Total Assets',
#  'Accounts Payable',
#  'Accrued Expenses',
#  'Short-Term Borrowings',
#  'Current Portion of LT Debt',
#  'Current Income Taxes Payable',
#  'Other Current Liabilities',
#  'Total Current Liabilities',
#  'Long-Term Debt',
#  'Pension & Other Post-Retire. Benefits',
#  'Def. Tax Liability, Non-Curr.',
#  'Capital Leases',
#  'Other Non-Current Liabilities',
#  'Total Liabilities',
#  'Common Stock',
#  'Additional Paid In Capital',
#  'Retained Earnings',
#  'Treasury Stock',
#  'Comprehensive Income and Other',
#  'Total Common Equity',
#  'Minority Interest',
#  'Total Equity',
#  'Total Liabilities And Equity',
#  'Total Shares Out. on Filing Date',
#  'Total Common Shares Outstanding',
#  'Book Value / Share',
#  'Tangible Book Value',
#  'Tangible Book Value Per Share',
#  'Total Debt',
#  'Net Debt',
#  'Land',
#  'Buildings, Total',
#  'Machinery, Total',
#  'Full Time Employees',
#  'Total Employees',
#  'Time']

# %%
for col in Tko_BalSheet.columns:
    print(col)
# Out:
# Cash And Equivalents
# Short Term Investments
# Trading Asset Securities
# Total Cash & ST Investments
# Accounts Receivable
# Total Receivables
# Inventory
# Prepaid Expenses
# Deferred Tax Assets Current
# Other Current Assets
# Total Current Assets
# Gross Property, Plant & Equipment
# Accumulated Depreciation
# Net Property, Plant & Equipment
# Long-Term Investments
# Goodwill
# Other Intangibles
# Deferred Tax Assets
# Other Long-Term Assets
# Total Assets
# Accounts Payable
# Accrued Expenses
# Short-Term Borrowings
# Current Portion of LT Debt
# Current Income Taxes Payable
# Other Current Liabilities
# Total Current Liabilities
# Long-Term Debt
# Pension & Other Post-Retire. Benefits
# Def. Tax Liability, Non-Curr.
# Capital Leases
# Other Non-Current Liabilities
# Total Liabilities
# Common Stock
# Additional Paid In Capital
# Retained Earnings
# Treasury Stock
# Comprehensive Income and Other
# Total Common Equity
# Minority Interest
# Total Equity
# Total Liabilities And Equity
# Total Shares Out. on Filing Date
# Total Common Shares Outstanding
# Book Value / Share
# Tangible Book Value
# Tangible Book Value Per Share
# Total Debt
# Net Debt
# Land
# Buildings, Total
# Machinery, Total
# Full Time Employees
# Total Employees
# Time

# %%
COL_NAMES = []
for col in Tko_BalSheet.columns:
    COL_NAMES.append(col)
    #print(col)
    
print("Col Names", len(COL_NAMES))
print("Set Col Names", len(set(COL_NAMES)))
# Out:
# Col Names 55
# Set Col Names 55

# %%
for element in COL_NAMES:
    x = COL_NAMES.count(element)
    if x > 1:
        print(element)

# %%
print("Col Names", COL_NAMES)
# Out:
# Col Names ['Cash And Equivalents', 'Total Cash & ST Investments', 'Accounts Receivable', 'Other Receivables', 'Total Receivables', 'Inventory', 'Finance Div. Loans and Leases', 'Deferred Tax Assets Current', 'Restricted Cash', 'Other Current Assets', 'Total Current Assets', 'Gross Property, Plant & Equipment', 'Accumulated Depreciation', 'Net Property, Plant & Equipment', 'Long-Term Investments', 'Goodwill', 'Other Intangibles', 'Finance Div. Loans and Leases', 'Deferred Charges', 'Other Long-Term Assets', 'Total Assets', 'Accounts Payable', 'Accrued Expenses', 'Short-Term Borrowings', 'Current Portion of LT Debt', 'Unearned Revenue, Current', 'Other Current Liabilities', 'Total Current Liabilities', 'Long-Term Debt', 'Finance Div. Other Non-Curr. Liab.', 'Pension & Other Post-Retire. Benefits', 'Def. Tax Liability, Non-Curr.', 'Other Non-Current Liabilities', 'Total Liabilities', 'Common Stock', 'Additional Paid In Capital', 'Retained Earnings', 'Treasury Stock', 'Comprehensive Income and Other', 'Total Common Equity', 'Minority Interest', 'Total Equity', 'Total Liabilities And Equity', 'Total Shares Out. on Filing Date', 'Total Common Shares Outstanding', 'Book Value / Share', 'Tangible Book Value', 'Tangible Book Value Per Share', 'Total Debt', 'Net Debt', 'LIFO Reserve, Total', 'Land', 'Buildings, Total', 'Machinery, Total', 'Full Time Employees', 'Total Employees']

# %%
print("Set Col Names", set(COL_NAMES))
# Out:
# Set Col Names {'Cash And Equivalents', 'Short-Term Borrowings', 'Total Shares Out. on Filing Date', 'Finance Div. Loans and Leases', 'Other Current Assets', 'LIFO Reserve, Total', 'Total Employees', 'Total Receivables', 'Other Long-Term Assets', 'Comprehensive Income and Other', 'Deferred Tax Assets Current', 'Goodwill', 'Pension & Other Post-Retire. Benefits', 'Total Equity', 'Tangible Book Value', 'Total Current Assets', 'Total Common Shares Outstanding', 'Deferred Charges', 'Accounts Payable', 'Unearned Revenue, Current', 'Book Value / Share', 'Full Time Employees', 'Accounts Receivable', 'Machinery, Total', 'Total Debt', 'Total Cash & ST Investments', 'Total Assets', 'Land', 'Retained Earnings', 'Treasury Stock', 'Net Property, Plant & Equipment', 'Total Current Liabilities', 'Accumulated Depreciation', 'Def. Tax Liability, Non-Curr.', 'Other Current Liabilities', 'Tangible Book Value Per Share', 'Long-Term Investments', 'Other Non-Current Liabilities', 'Accrued Expenses', 'Minority Interest', 'Other Intangibles', 'Common Stock', 'Gross Property, Plant & Equipment', 'Net Debt', 'Buildings, Total', 'Total Liabilities', 'Inventory', 'Additional Paid In Capital', 'Other Receivables', 'Restricted Cash', 'Finance Div. Other Non-Curr. Liab.', 'Long-Term Debt', 'Current Portion of LT Debt', 'Total Common Equity', 'Total Liabilities And Equity'}

# %%
#['Total Cash & ST Investments', 'Total Receivables', 'Total Current Assets', 'Total Assets', 'Total Current Liabilities', 'Total Liabilities','Total Common Shares Outstanding', 'Book Value / Share','Tangible Book Value', 'Tangible Book Value Per Share', 'Total Debt','Net Debt']

# %%
# Keeping certain columns to standardise all Income statements by keeping the same parameters
Tko_BalSheet = Tko_BalSheet.reindex(columns= ['Total Cash & ST Investments', 'Total Receivables', 'Total Current Assets'] )
                    
Tko_BalSheet['Company'] = company_name
                
from datetime import datetime
orig_dates_list = Tko_BalSheet.index.tolist()
converted_dates_list = []

for element in orig_dates_list:
    datetime_obj = datetime.strptime(element, '%b %Y')
    converted_dates_list.append(datetime_obj)

Tko_BalSheet['Time'] = converted_dates_list
                
comp = Tko_BalSheet['Company']
time = Tko_BalSheet['Time']
Tko_BalSheet.drop(labels=['Company', 'Time' ], axis=1,inplace = True)
Tko_BalSheet.insert(0, 'Company', comp)
Tko_BalSheet.insert(1, 'Time', time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-e43ed3c13a26> in <module>
#       1 # Keeping certain columns to standardise all Income statements by keeping the same parameters
# ----> 2 Tko_BalSheet = Tko_BalSheet.reindex(columns= ['Total Cash & ST Investments', 'Total Receivables', 'Total Current Assets'] )
#       3
#       4 Tko_BalSheet['Company'] = company_name
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3807         kwargs.pop('axis', None)
#    3808         kwargs.pop('labels', None)
# -> 3809         return super(DataFrame, self).reindex(**kwargs)
#    3810
#    3811     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4354         # perform the reindex on the axes
#    4355         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 4356                                   fill_value, copy).__finalize__(self)
#    4357
#    4358     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3734         if columns is not None:
#    3735             frame = frame._reindex_columns(columns, method, copy, level,
# -> 3736                                            fill_value, limit, tolerance)
#    3737
#    3738         index = axes['index']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3759         return self._reindex_with_indexers({1: [new_columns, indexer]},
#    3760                                            copy=copy, fill_value=fill_value,
# -> 3761                                            allow_dups=False)
#    3762
#    3763     def _reindex_multi(self, axes, copy, fill_value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4488                                                 fill_value=fill_value,
#    4489                                                 allow_dups=allow_dups,
# -> 4490                                                 copy=copy)
#    4491
#    4492         if copy and new_data is self._data:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1222         # some axes don't allow reindexing with dups
#    1223         if not allow_dups:
# -> 1224             self.axes[axis]._can_reindex(indexer)
#    1225
#    1226         if axis >= self.ndim:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3085         # trying to reindex on an axis with duplicates
#    3086         if not self.is_unique and len(indexer):
# -> 3087             raise ValueError("cannot reindex from a duplicate axis")
#    3088
#    3089     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis
