# %%
import os
import pymysql
import pandas as pd
import numpy as np
import re
from pandas.io import sql
import MySQLdb
from sqlalchemy import create_engine

# %%
from pandas.io import sql
import MySQLdb

conn = MySQLdb.connect(
    host="localhost",
    port=int(3306),
    user="pythonlink",
    passwd="pythonlinkp",
    db="stock_forecast_v1",
    charset='utf8mb4'
)

data = pd.read_sql_query("SELECT * FROM delta_balsheets500_withpricechange",
    conn)
data
# Out:
#      Company        Time  Total Assets  Total Liabilities  Total Equity  \
# 0          A  2011-10-01        -639.0            -1719.0        1080.0
# 1          A  2012-10-01        1479.0              610.0         869.0
# 2          A  2013-10-01         150.0               46.0         104.0
# 3          A  2014-10-01         129.0              114.0          15.0
# 4          A  2015-10-01       -3336.0            -2202.0       -1134.0
# 5          A  2016-10-01         315.0              239.0          76.0
# 6          A  2017-10-01         632.0               43.0         589.0
# 7          A  2018-10-01         115.0              379.0        -264.0
# 8          A  2019-10-01         911.0              734.0         177.0
# 9        AAL  2011-12-01       -1240.0             1926.0       -3166.0
# 10       AAL  2012-12-01        -338.0              538.0        -876.0
# 11       AAL  2013-12-01       18768.0            13512.0        5256.0
# ...

# %%
# Shuffling the data to create random arrangement of data instances
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#      Company        Time  Total Assets  Total Liabilities  Total Equity  \
# 0       SIRI  2019-12-01        2976.0             1895.0        1081.0
# 1       NEWT  2015-12-01          50.6               13.1          37.5
# 2        ADM  2019-12-01        3164.0             2926.0         238.0
# 3        PXD  2017-12-01         544.0             -324.0         868.0
# 4       TROW  2018-12-01         153.9              106.5          47.4
# 5        PRU  2013-12-01       22546.0            25777.0       -3231.0
# 6        LEG  2017-12-01         566.7              469.9          96.8
# 7        ADS  2012-12-01        3019.9             2667.4         352.5
# 8        PPG  2018-12-01        -523.0              417.0        -940.0
# 9         VZ  2015-12-01       11559.0             7393.0        4166.0
# 10       CAT  2012-12-01        7752.0             3572.0        4180.0
# 11       SWK  2017-12-01        3462.8             1531.4        1931.4
# ...

# %%
data.to_csv(r'C:\Users\conor\Documents\MScAIProject\MSc_AI_Project\Data\Testing\RawFilings_RawPrice\BalanceSheet\HyperparameterTuning\DeltaBS_data.csv', index = False)

# %%
BS_train_data = data[0:4000]
BS_train_data
# Out:
#      Company       Time Total Assets Total Liabilities Total Equity  \
# 0        FSI 2011-12-01         14.5               3.9         10.6
# 1        PFG 2011-12-01     147361.7          137967.8       9393.9
# 2        CTL 2014-12-01      49103.0           34080.0      15023.0
# 3       HWKN 2013-03-01        222.1              52.0        170.2
# 4        KMX 2014-02-01      11707.2            8390.2       3317.0
# 5        IEX 2017-12-01       3399.6            1513.1       1886.5
# 6       SLGN 2014-12-01       3274.1            2564.2          710
# 7       CASY 2019-04-01       3731.4            2322.6       1408.8
# 8        ACN 2014-08-01      17930.5           11645.1       6285.3
# 9       SLGN 2010-12-01       2176.0            1622.4        553.6
# 10       LUV 2016-12-01      23286.0           14845.0       8441.0
# 11        DE 2011-10-01      48207.4           41392.5       6814.9
# 12       CXO 2013-12-01       9591.2            5833.2       3757.9
# ...

# %%
#BS_train_data.to_csv(r'C:\Users\conor\Documents\MScAIProject\MSc_AI_Project\Data\Testing\RawFilings_RawPrice\BalanceSheet\HyperparameterTuning\BS_train_data.csv', index = False)

# %%
BS_validation_data = data[4000:5000]
BS_validation_data
# Out:
#      Company       Time Total Assets Total Liabilities Total Equity  \
# 4000    AMGN 2014-12-01      69009.0           43231.0      25778.0
# 4001     WRB 2011-12-01      18403.9           14443.0       3960.9
# 4002     PPL 2014-12-01      48606.0           34978.0      13628.0
# 4003     GPC 2013-12-01       7680.3            4321.5       3358.8
# 4004     HAL 2011-12-01      23677.0           10461.0      13216.0
# 4005     EPD 2013-12-01      40138.7           24698.3      15440.4
# 4006    NLOK 2016-04-01      11767.0            8091.0       3676.0
# 4007     WWE 2015-12-01        409.1             199.8        209.3
# 4008     MHK 2014-12-01       8285.5            3862.7       4422.8
# 4009   BRK.B 2014-12-01     525867.0          282840.0     243027.0
# 4010     CPE 2016-12-01       2267.6             534.2       1733.4
# 4011     AOS 2014-12-01       2515.3            1134.0       1381.3
# 4012     CCL 2019-11-01      45058.0           19693.0      25365.0
# ...

# %%
#BS_validation_data.to_csv(r'C:\Users\conor\Documents\MScAIProject\MSc_AI_Project\Data\Testing\RawFilings_RawPrice\BalanceSheet\HyperparameterTuning\BS_validation_data.csv', index = False)
